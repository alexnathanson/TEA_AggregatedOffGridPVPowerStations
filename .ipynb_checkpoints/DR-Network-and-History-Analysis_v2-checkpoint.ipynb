# %% [markdown]
# ##### DR History Analysis
#
# This script looks at 2025 networks and DR event logs from 2011 through 2024. The goal is to inform maximum DR participation estimates. I am primarily concerned with the frequency and type of DLRP events by network in order to understand if there are any generalizable characteristics of networks with immediate or contingent DLRP events.
#
# ## Notes
# * Network tiers shift slightly year to year, so it can't be relied on for an analysis
# * Some years have different asterisk meanings. See this document for details https://www.coned.com/-/media/files/coned/documents/save-energy-money/rebates-incentives-tax-credits/smart-usage-rewards/demand-response-events.pdf?la=en
# * Brownsville Networks = Crown Heights, Richmond Hill, Ridgewood

# %%
import pandas as pd
import matplotlib.pyplot as plt  # for visualization
from datetime import datetime
from statistics import median

# %% [markdown]
# # 2025 Networks

# %%
# read in hardware data to dataframe
networks_df = pd.read_csv('data/conEdNetworks2025.csv')

networks_df.head()
# Out:
#   borough          network start time end time  tier
# 0   bronx    central bronx      16:00    20:00     2
# 1   bronx          fordham      16:00    20:00     2
# 2   bronx  northeast bronx      16:00    20:00     2
# 3   bronx        riverdale      16:00    20:00     1
# 4   bronx  southeast bronx      16:00    20:00     1

# %%
networks_df.shape
# Out:
# (82, 5)

# %%
allN = list(networks_df['network'])
allN
# Out:
# ['central bronx',
#  'fordham',
#  'northeast bronx',
#  'riverdale',
#  'southeast bronx',
#  'west bronx',
#  'bay ridge',
#  'borough hall',
#  'brighton beach',
#  'crown heights',
#  'flatbush',
#  'ocean parkway',
#  'park slope',
#  'prospect park',
#  'ridgewood',
#  'sheepshead bay',
#  'williamsburg',
#  'battery park city',
#  'beekman',
#  'bowling green',
#  'canal',
#  'central park',
#  'chelsea',
#  'city hall',
#  'columbus circle',
#  'cooper square',
#  'cortlandt',
#  'empire',
#  'fashion',
#  'freedom',
#  'fulton',
#  'grand central',
#  'greeley square',
#  'greenwich',
#  'harlem',
#  'herald square',
#  'hudson',
#  'hunter',
#  'kips bay',
#  'lenox hill',
#  'lincoln square',
#  'madison square',
#  'midtown west',
#  'park place',
#  'pennsylvania',
#  'plaza',
#  'rockefeller center',
#  'roosevelt',
#  'sheridan square',
#  'sutton',
#  'times square',
#  'triboro',
#  'turtle bay',
#  'washington heights',
#  'yorkville',
#  'borden',
#  'flushing',
#  'jackson heights',
#  'jamaica',
#  'long island city',
#  'maspeth',
#  'rego park',
#  'richmond hill',
#  'sunnyside',
#  'fox hills',
#  'fresh kills',
#  'wainwright',
#  'willowbrook',
#  'woodrow',
#  'buchanan',
#  'cedar street',
#  'elmsford no. 2',
#  'granite hill',
#  'grasslands',
#  'harrison',
#  'millwood west',
#  'mohansic',
#  'washington street',
#  'white plains',
#  'pleasantville',
#  'rockview',
#  'ossining west']

# %%
# list(networks_df[networks_df['network']=='fordham']['borough'])[0]

# %%
#get list of non-manhattan networks
nM = list(networks_df[networks_df['borough']!= 'manhattan']['network'])
print(nM)

#get list of manhattan networks
mN =  list(networks_df[networks_df['borough']== 'manhattan']['network'])
# Out:
# ['central bronx', 'fordham', 'northeast bronx', 'riverdale', 'southeast bronx', 'west bronx', 'bay ridge', 'borough hall', 'brighton beach', 'crown heights', 'flatbush', 'ocean parkway', 'park slope', 'prospect park', 'ridgewood', 'sheepshead bay', 'williamsburg', 'borden', 'flushing', 'jackson heights', 'jamaica', 'long island city', 'maspeth', 'rego park', 'richmond hill', 'sunnyside', 'fox hills', 'fresh kills', 'wainwright', 'willowbrook', 'woodrow', 'buchanan', 'cedar street', 'elmsford no. 2', 'granite hill', 'grasslands', 'harrison', 'millwood west', 'mohansic', 'washington street', 'white plains', 'pleasantville', 'rockview', 'ossining west']

# %%
#get representative networks
#repNet = {}
for t in range(2):
    tN = networks_df.loc[networks_df['tier']== t+1]
    for ti in ['11:00','14:00','16:00','19:00']:
        tNT = tN.loc[tN['start time']==ti]
        
        for b in range(2):
            if b == 0:
                bL = ['bronx', 'brooklyn', 'manhattan', 'queens']
            else:
                bL = ['staten island','westchester']
                     
            tNTB = tNT.loc[tNT['borough'].isin(bL)]
            print('B' + str(b+1) +'_T'+str(t+1) + '_S'+ str(ti) + ': ' + str(tNTB.shape[0]))
# Out:
# B1_T1_S11:00: 23
# B2_T1_S11:00: 0
# B1_T1_S14:00: 18
# B2_T1_S14:00: 4
# B1_T1_S16:00: 13
# B2_T1_S16:00: 14
# B1_T1_S19:00: 0
# B2_T1_S19:00: 0
# B1_T2_S11:00: 0
# B2_T2_S11:00: 0
# B1_T2_S14:00: 0
# B2_T2_S14:00: 0
# B1_T2_S16:00: 10
# B2_T2_S16:00: 0
# B1_T2_S19:00: 0
# B2_T2_S19:00: 0

# %%
#percentage of tier 2 networks
networks_df[networks_df['tier']==2].shape[0]/int(networks_df.shape[0])
# Out:
# 0.12195121951219512

# %% [markdown]
# # DR Event Logs

# %%
# read in logs to dataframe

log_df = pd.read_csv('data/DR-activitylog-cleaned_2024.csv')

#convert event dates to datetime format
log_df['Event Date'] = pd.to_datetime(log_df['Event Date'])

print(log_df.shape)
log_df.head()
# Out:
# (938, 9)
#   Event Date Administrator Program Start Time End Time Event Duration  \
# 0 2011-06-08    Con Edison     DLC      15:00    16:00           1:00
# 1 2011-06-08    Con Edison    DLRP      15:00    16:00           1:00
# 2 2011-06-08    Con Edison    RSAP      16:00    17:00           1:00
# 3 2011-06-09    Con Edison    CSRP      14:00    15:00           1:00
# 4 2011-06-09    Con Edison    CSRP      17:00    18:00           1:00
#
#   Zone/Network Event/Test Event Type
# 0          All       Test        NaN
# 1          All       Test        NaN
# 2       Zone J       Test        NaN
# 3          All       Test        NaN
# 4          All       Test        NaN

# %%
# filter out all NYISO
flog_df = log_df[log_df['Administrator']=='Con Edison']
print(flog_df.shape)

#filter out tests
flog_df = flog_df[log_df['Event/Test']!='Test']
print(flog_df.shape)
flog_df.head()
# Out:
# (846, 9)
# (760, 9)
# C:\Users\alexn\AppData\Local\Temp\ipykernel_56540\294374127.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   flog_df = flog_df[log_df['Event/Test']!='Test']
#    Event Date Administrator     Program Start Time End Time Event Duration  \
# 7  2011-07-21    Con Edison         DLC      13:00    18:00           5:00
# 8  2011-07-21    Con Edison        RSAP      11:00    19:00           8:00
# 9  2011-07-21    Con Edison    CSRP-Day      12:00    17:00           5:00
# 10 2011-07-21    Con Edison  CSRP-Night      17:00    22:00           5:00
# 13 2011-07-22    Con Edison         DLC       7:00    15:00           8:00
#
#       Zone/Network Event/Test Event Type
# 7              All      Event        NaN
# 8           Zone J      Event        NaN
# 9              All      Event        NaN
# 10             All      Event        NaN
# 13  Elmsford No. 2      Event        NaN

# %%
flog_df.tail()
# Out:
#     Event Date Administrator Program Start Time End Time Event Duration  \
# 930 2024-08-03    Con Edison   DLRP*      16:00    20:00           4:00
# 931 2024-08-03    Con Edison   DLRP*      16:00    20:00           4:00
# 932 2024-08-03    Con Edison   DLRP*      15:00    21:00           6:00
# 933 2024-08-03    Con Edison   DLRP*      15:30    21:30           6:00
# 934 2024-08-03    Con Edison   DLRP*      17:00    23:00           6:00
#
#        Zone/Network Event/Test        Event Type
# 930     Fresh Kills      Event  DLRP Contingency
# 931    Cedar Street      Event  DLRP Contingency
# 932         Fordham      Event    DLRP Immediate
# 933   Fordham SC 11      Event    DLRP Immediate
# 934  Elmsford No. 2      Event    DLRP Immediate

# %%
# Remove asterisks from the column
flog_df['Program'] = flog_df['Program'].str.replace('*', '', regex=False)

# %% [markdown]
# ## DLRP analysis

# %%
#filter out non DLRP events
dlog_df = flog_df[flog_df['Program'].isin(['DLRP'])]

print(dlog_df.shape)
dlog_df.head()
# Out:
# (171, 9)
#    Event Date Administrator Program Start Time End Time Event Duration  \
# 25 2011-07-22    Con Edison    DLRP       7:00    15:00           8:00
# 26 2011-07-22    Con Edison    DLRP       7:00    15:00           8:00
# 27 2011-07-22    Con Edison    DLRP      18:00    23:00           5:00
# 28 2011-07-22    Con Edison    DLRP      18:00    23:00           5:00
# 29 2011-07-22    Con Edison    DLRP      18:00    23:00           5:00
#
#       Zone/Network Event/Test Event Type
# 25  Elmsford No. 2      Event        NaN
# 26         Maspeth      Event        NaN
# 27   Richmond Hill      Event        NaN
# 28       Fox Hills      Event        NaN
# 29  Sheepshead Bay      Event        NaN

# %%
#filter out NaN event types
dlog_df = dlog_df[flog_df['Event Type'].notnull()]

print(dlog_df.shape)
dlog_df.head()
# Out:
# (135, 9)
# C:\Users\alexn\AppData\Local\Temp\ipykernel_56540\2038490168.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dlog_df = dlog_df[flog_df['Event Type'].notnull()]
#     Event Date Administrator Program Start Time End Time Event Duration  \
# 171 2016-07-15    Con Edison    DLRP      14:00    20:00           6:00
# 173 2016-07-22    Con Edison    DLRP      17:00    23:00           6:00
# 174 2016-07-23    Con Edison    DLRP      22:00     0:00           2:00
# 176 2016-07-24    Con Edison    DLRP       6:00    10:00           4:00
# 195 2016-08-11    Con Edison    DLRP      14:00    20:00           6:00
#
#       Zone/Network Event/Test   Event Type
# 171    Fresh Kills      Event    Immediate
# 173      Fox Hills      Event    Immediate
# 174        Triboro      Event    Immediate
# 176      Riverdale      Event  Contingency
# 195  Crown Heights      Event  Contingency

# %%
#args: list of networks
brownsvilleNetworks = ['crown heights', 'richmond hill', 'ridgewood']

def getUnique(l):
    nL = []
    #loop through list
    for n in l:
        n = n.lower()
        #replace Brownsville group with actual network names
        if n == 'brownsville*':
            for b in brownsvilleNetworks :
                if b not in nL:
                    nL.append(b)
        elif n == 'all^':
            #in 2019 All^ exlcludes Manhattan, Borough Hall, and Brownsville
            #in 2020 All^ excludes Brownsville Networks but this is not present in the filtered data
            #loop through all networks
            for nn in allN:
                #exclude browseville networks
                if nn not in brownsvilleNetworks:
                    #exclude manhattan networks
                    if nn not in mN:
                        if nn != 'borough hall':
                            #check if already in list
                            if nn not in nL:
                                nL.append(nn) 
        elif n == 'non-manhattan**':
            #in 2019 Non-Manhattan** excludes Brownsville (BQDM) networks but this is not present in the filtered data
            #in 2020 Non-Manhattan** excludes Borough Hall
            #loop through all non-manhattan networks
            for nn in nM:
                if nn not in nL:
                    if nn != 'borough hall':
                        nL.append(nn)
        elif n == 'non-manhattan***':
            #in 2020 Non-Manhattan*** includes Washington Heights in Manhattan. Excludes Borough Hall
            for nn in nM:
                if nn not in nL:
                    if nn != 'borough hall':
                        nL.append(nn)
            if 'washington heights' not in nL:
                nL.append('washington heights')
        else:
            if 'sc 11' in n:
                n = n.replace('sc 11','').strip()
            if n not in nL:
                nL.append(n)
        
    return nL

# %%
#dlog_df['Zone/Network'] = dlog_df['Zone/Network'].str.replace('SC 11', '', regex=False)

# %%
print(dlog_df['Zone/Network'].unique())

#list of networks that have had DLRP events of either type
DLRPuN = getUnique(dlog_df['Zone/Network'].unique())

#print network names
print(DLRPuN)

#print amount of networks
print(len(DLRPuN))

#print percentage of total networks
len(DLRPuN)/networks_df.shape[0]
# Out:
# ['Fresh Kills' 'Fox Hills' 'Triboro' 'Riverdale' 'Crown Heights'
#  'Ridgewood' 'Richmond Hill' 'Sheepshead Bay' 'Williamsburg'
#  'Prospect Park' 'Central Park' 'Madison Square' 'Cooper Square'
#  'Brownsville*' 'Willowbrook' 'All^' 'Flatbush' 'Wainwright' 'Bay Ridge'
#  'Rego Park' 'Non-Manhattan**' 'Maspeth' 'Southeast Bronx'
#  'Non-Manhattan***' 'Borough Hall' 'Yorkville' 'Jamaica' 'City Hall'
#  'Ossining West' 'Park Slope' 'Central Bronx' 'Cedar Street'
#  'Washington Street' 'Elmsford No. 2' 'Jackson Heights' 'Borden'
#  'Sunnyside' 'Granite Hill' 'White Plains' 'Sutton' 'Fordham'
#  'Fordham SC 11']
# ['fresh kills', 'fox hills', 'triboro', 'riverdale', 'crown heights', 'ridgewood', 'richmond hill', 'sheepshead bay', 'williamsburg', 'prospect park', 'central park', 'madison square', 'cooper square', 'willowbrook', 'central bronx', 'fordham', 'northeast bronx', 'southeast bronx', 'west bronx', 'bay ridge', 'brighton beach', 'flatbush', 'ocean parkway', 'park slope', 'borden', 'flushing', 'jackson heights', 'jamaica', 'long island city', 'maspeth', 'rego park', 'sunnyside', 'wainwright', 'woodrow', 'buchanan', 'cedar street', 'elmsford no. 2', 'granite hill', 'grasslands', 'harrison', 'millwood west', 'mohansic', 'washington street', 'white plains', 'pleasantville', 'rockview', 'ossining west', 'washington heights', 'borough hall', 'yorkville', 'city hall', 'sutton']
# 52
# 0.6341463414634146

# %%
#networks that have never experience DLRP events
nonDLRP = []
for n in allN:
    if n not in DLRPuN:
        nonDLRP.append(n)

print(len(nonDLRP))
display(networks_df[networks_df['network'].isin(nonDLRP)])
# Out:
# 30
#       borough             network start time end time  tier
# 17  manhattan   battery park city      14:00    18:00     1
# 18  manhattan             beekman      11:00    15:00     1
# 19  manhattan       bowling green      11:00    15:00     1
# 20  manhattan               canal      11:00    15:00     1
# 22  manhattan             chelsea      11:00    15:00     1
# 24  manhattan     columbus circle      14:00    18:00     1
# 26  manhattan           cortlandt      11:00    15:00     1
# 27  manhattan              empire      14:00    18:00     1
# 28  manhattan             fashion      11:00    15:00     1
# 29  manhattan             freedom      11:00    15:00     1
# 30  manhattan              fulton      11:00    15:00     1
# 31  manhattan       grand central      11:00    15:00     1
# 32  manhattan      greeley square      11:00    15:00     1
# 33  manhattan           greenwich      14:00    18:00     1
# 34  manhattan              harlem      14:00    18:00     1
# 35  manhattan       herald square      11:00    15:00     1
# 36  manhattan              hudson      11:00    15:00     1
# 37  manhattan              hunter      11:00    15:00     1
# 38  manhattan            kips bay      11:00    15:00     1
# 39  manhattan          lenox hill      14:00    18:00     1
# 40  manhattan      lincoln square      11:00    15:00     1
# 42  manhattan        midtown west      11:00    15:00     1
# 43  manhattan          park place      14:00    18:00     1
# 44  manhattan        pennsylvania      11:00    15:00     1
# 45  manhattan               plaza      11:00    15:00     1
# 46  manhattan  rockefeller center      11:00    15:00     1
# 47  manhattan           roosevelt      14:00    18:00     1
# 48  manhattan     sheridan square      14:00    18:00     1
# 50  manhattan        times square      11:00    15:00     1
# 52  manhattan          turtle bay      11:00    15:00     1

# %% [markdown]
# ### Analysis of Immediate Events

# %%
#immediate events
#filter out NaN event types
elog_df = dlog_df[(flog_df['Event Type']=='Immediate') | (flog_df['Event Type']=='DLRP Immediate')]

uniIE = getUnique(elog_df['Zone/Network'].unique())

print(len(uniIE))
print(len(uniIE)/networks_df.shape[0])
print(uniIE)
elog_df.head()
# Out:
# 25
# 0.3048780487804878
# ['fresh kills', 'fox hills', 'triboro', 'williamsburg', 'prospect park', 'willowbrook', 'flatbush', 'bay ridge', 'southeast bronx', 'yorkville', 'maspeth', 'central park', 'jamaica', 'rego park', 'city hall', 'ossining west', 'ridgewood', 'central bronx', 'cedar street', 'washington street', 'elmsford no. 2', 'jackson heights', 'granite hill', 'white plains', 'fordham']
# C:\Users\alexn\AppData\Local\Temp\ipykernel_56540\2201559310.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   elog_df = dlog_df[(flog_df['Event Type']=='Immediate') | (flog_df['Event Type']=='DLRP Immediate')]
#     Event Date Administrator Program Start Time End Time Event Duration  \
# 171 2016-07-15    Con Edison    DLRP      14:00    20:00           6:00
# 173 2016-07-22    Con Edison    DLRP      17:00    23:00           6:00
# 174 2016-07-23    Con Edison    DLRP      22:00     0:00           2:00
# 215 2016-08-12    Con Edison    DLRP      17:00    22:00           5:00
# 216 2016-08-12    Con Edison    DLRP      16:00     0:00           8:00
#
#     Zone/Network Event/Test Event Type
# 171  Fresh Kills      Event  Immediate
# 173    Fox Hills      Event  Immediate
# 174      Triboro      Event  Immediate
# 215    Fox Hills      Event  Immediate
# 216  Fresh Kills      Event  Immediate

# %%
#get representative networks for those that have had DLRP immediate events

nG = []
for iN in getUnique(uniIE):
    tempN = networks_df[networks_df['network']== iN.lower()]
    if list(tempN['borough'])[0] in ['staten island','westchester']:
        nG.append("T" + str(list(tempN['tier'])[0]) + " B2 " + str(list(tempN['start time'])[0]))
    else:
        nG.append("T" + str(list(tempN['tier'])[0]) + " B1 " + str(list(tempN['start time'])[0]))
        
    
print(list(nG))

nGDict = dict(zip(set(nG),[0] * len(set(nG))))

for n in nG:
    nGDict[n] = nGDict[n] + 1
    
nGDict
# set(nG)
        #repNet = {}
# for t in range(2):
#     tN = networks_df.loc[networks_df['tier']== t+1]
#     for ti in ['11:00','14:00','16:00','19:00']:
#         tNT = tN.loc[tN['start time']==ti]
        
#         for b in range(2):
#             if b == 0:
#                 bL = ['bronx', 'brooklyn', 'manhattan', 'queens']
#             else:
#                 bL = 
                     
#             tNTB = tNT.loc[tNT['borough'].isin(bL)]
#             print('B' + str(b+1) +'_T'+str(t+1) + '_S'+ str(ti) + ': ' + str(tNTB.shape[0]))
# Out:
# ['T1 B2 16:00', 'T1 B2 16:00', 'T1 B1 14:00', 'T2 B1 16:00', 'T1 B1 16:00', 'T1 B2 16:00', 'T1 B1 16:00', 'T1 B1 14:00', 'T1 B1 16:00', 'T1 B1 14:00', 'T1 B1 16:00', 'T1 B1 16:00', 'T2 B1 16:00', 'T1 B1 16:00', 'T1 B1 11:00', 'T1 B2 16:00', 'T2 B1 16:00', 'T2 B1 16:00', 'T1 B2 16:00', 'T1 B2 16:00', 'T1 B2 16:00', 'T2 B1 16:00', 'T1 B2 16:00', 'T1 B2 14:00', 'T2 B1 16:00']
# {'T1 B2 14:00': 1,
#  'T2 B1 16:00': 6,
#  'T1 B1 14:00': 3,
#  'T1 B2 16:00': 8,
#  'T1 B1 11:00': 1,
#  'T1 B1 16:00': 6}

# %%
# Histogram of networks with DLRP events

plt.figure(figsize=(14,7)) # Make it 14x7 inch
plt.hist(elog_df['Zone/Network'], bins=len(elog_df['Zone/Network'].unique()), facecolor = '#2ab0ff', edgecolor='#169acf', linewidth=0.5)
plt.title('Immediate Events by Network') 
plt.xlabel('Networks') 
plt.xticks(rotation='vertical')
plt.ylabel('Number of Immediate Events 2016-2023') 
plt.show()

# %%
# bL = []
# for r in range(elog_df.shape[0]):
#     #print(elog_df.iloc[r])
#     mn = elog_df.iloc[r]['Zone/Network'].lower()
#     if 'sc 11' in mn:
#         mn = mn.replace('sc 11','')
#     print(mn)

#     mb = list(networks_df[networks_df['network'].str.lower()==mn.lower()]['borough'])[0]    
#     bL.append(mb)
             
# elog_df['borough'] = bL

# plt.figure(figsize=(14,7)) # Make it 14x7 inch
# plt.hist(elog_df['borough'], bins=len(getUnique(elog_df['Zone/Network'].unique())), facecolor = '#2ab0ff', edgecolor='#169acf', linewidth=0.5)
# plt.title('Immediate Events by Borough ') 
# plt.xlabel('Networks') 
# plt.xticks(rotation='vertical')
# plt.ylabel('Number of Immediate Events 2016-2024') 
# plt.show()

# %%
#investigate staten island events
elog_df[elog_df['borough'] == 'staten island']
# Out:
#     Event Date Administrator Program Start Time End Time Event Duration  \
# 171 2016-07-15    Con Edison    DLRP      14:00    20:00           6:00
# 173 2016-07-22    Con Edison    DLRP      17:00    23:00           6:00
# 215 2016-08-12    Con Edison    DLRP      17:00    22:00           5:00
# 216 2016-08-12    Con Edison    DLRP      16:00     0:00           8:00
# 231 2016-08-13    Con Edison    DLRP      14:00    22:00           8:00
# 232 2016-08-13    Con Edison    DLRP      14:00    22:00           8:00
# 296 2018-05-03    Con Edison    DLRP      16:00    22:00           6:00
# 305 2018-06-18    Con Edison    DLRP      17:00    23:00           6:00
# 420 2019-07-17    Con Edison    DLRP      17:00    23:00           6:00
# 421 2019-07-17    Con Edison    DLRP      17:00    23:00           6:00
# 674 2021-08-25    Con Edison    DLRP      21:00     0:00           3:00
# 683 2022-05-31    Con Edison    DLRP      16:00    22:00           6:00
# 684 2022-05-31    Con Edison    DLRP      18:00    23:00           5:00
# 700 2022-07-20    Con Edison    DLRP      17:30    23:30           6:00
# 792 2023-07-05    Con Edison    DLRP      18:30    23:30           5:00
# 834 2023-09-05    Con Edison    DLRP      16:30    23:30           7:00
# 840 2023-09-06    Con Edison    DLRP      18:00     0:00           6:00
# 856 2023-09-08    Con Edison    DLRP      15:30    21:30           6:00
# 862 2023-09-27    Con Edison    DLRP      12:30    18:30           6:00
#
#     Zone/Network Event/Test Event Type        borough
# 171  Fresh Kills      Event  Immediate  staten island
# 173    Fox Hills      Event  Immediate  staten island
# 215    Fox Hills      Event  Immediate  staten island
# 216  Fresh Kills      Event  Immediate  staten island
# 231    Fox Hills      Event  Immediate  staten island
# 232  Fresh Kills      Event  Immediate  staten island
# 296    Fox Hills      Event  Immediate  staten island
# 305    Fox Hills      Event  Immediate  staten island
# 420    Fox Hills      Event  Immediate  staten island
# 421  Willowbrook      Event  Immediate  staten island
# 674  Fresh Kills      Event  Immediate  staten island
# 683  Fresh Kills      Event  Immediate  staten island
# 684    Fox Hills      Event  Immediate  staten island
# 700  Fresh Kills      Event  Immediate  staten island
# 792    Fox Hills      Event  Immediate  staten island
# 834  Fresh Kills      Event  Immediate  staten island
# 840  Fresh Kills      Event  Immediate  staten island
# 856  Fresh Kills      Event  Immediate  staten island
# 862    Fox Hills      Event  Immediate  staten island

# %%
tL = []
for r in range(elog_df.shape[0]):
    mn = elog_df.iloc[r]['Zone/Network'].lower()
    if 'sc 11' in mn:
        mn = mn.replace('sc 11','')
    try:
        mb = list(networks_df[networks_df['network'].str.lower()==mn]['tier'])[0]   
        tL.append(mb)
    except:
        print(mn)
        
elog_df['tier'] = tL
#elog_df.head()

plt.figure(figsize=(14,7)) # Make it 14x7 inch
plt.hist(elog_df['tier'], bins=2, facecolor = '#2ab0ff', edgecolor='#169acf', linewidth=0.5)
plt.title('Immediate Events by 2024 Tier ') 
plt.xlabel('tier') 
# plt.xticks(rotation='vertical')
plt.ylabel('Number of Immediate Events 2016-2023') 
plt.show()
# Out:
# fordham
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[309], line 12
#       9     except:
#      10         print(mn)
# ---> 12 elog_df['tier'] = tL
#      13 #elog_df.head()
#      15 plt.figure(figsize=(14,7)) # Make it 14x7 inch
#
# File ~\Documents\RPI\TEA_AggregatedOffGridPVPowerStations\venv\Lib\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File ~\Documents\RPI\TEA_AggregatedOffGridPVPowerStations\venv\Lib\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)   4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
#    4529         and not isinstance(value.dtype, ExtensionDtype)
#    4530     ):
#    4531         # broadcast across multiple columns if necessary
#    4532         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\Documents\RPI\TEA_AggregatedOffGridPVPowerStations\venv\Lib\site-packages\pandas\core\frame.py:5266, in DataFrame._sanitize_column(self, value)
#    5263     return _reindex_for_setitem(value, self.index)
#    5265 if is_list_like(value):
# -> 5266     com.require_length_match(value, self.index)
#    5267 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268 if (
#    5269     isinstance(value, Index)
#    5270     and value.dtype == "object"
#    (...)   5273     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5274     # this deprecation
#
# File ~\Documents\RPI\TEA_AggregatedOffGridPVPowerStations\venv\Lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (55) does not match length of index (56)

# %%
#convert start times to datetime format
elog_df['DT Format'] = pd.to_datetime(elog_df['Start Time'], format='%H:%M')
elog_df['Start Time Float'] = elog_df['DT Format'].dt.hour + (elog_df['DT Format'].dt.minute/60)
#convert to float
elog_df['Start Time Float'].apply(lambda x: float(x))

elog_df.head()
# Out:
# C:\Users\alexn\AppData\Local\Temp\ipykernel_56540\3012162079.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elog_df['DT Format'] = pd.to_datetime(elog_df['Start Time'], format='%H:%M')
# C:\Users\alexn\AppData\Local\Temp\ipykernel_56540\3012162079.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elog_df['Start Time Float'] = elog_df['DT Format'].dt.hour + (elog_df['DT Format'].dt.minute/60)
#     Event Date Administrator Program Start Time End Time Event Duration  \
# 171 2016-07-15    Con Edison    DLRP      14:00    20:00           6:00
# 173 2016-07-22    Con Edison    DLRP      17:00    23:00           6:00
# 174 2016-07-23    Con Edison    DLRP      22:00     0:00           2:00
# 215 2016-08-12    Con Edison    DLRP      17:00    22:00           5:00
# 216 2016-08-12    Con Edison    DLRP      16:00     0:00           8:00
#
#     Zone/Network Event/Test Event Type           DT Format  Start Time Float
# 171  Fresh Kills      Event  Immediate 1900-01-01 14:00:00              14.0
# 173    Fox Hills      Event  Immediate 1900-01-01 17:00:00              17.0
# 174      Triboro      Event  Immediate 1900-01-01 22:00:00              22.0
# 215    Fox Hills      Event  Immediate 1900-01-01 17:00:00              17.0
# 216  Fresh Kills      Event  Immediate 1900-01-01 16:00:00              16.0

# %%
print('total immediate events:')
print(elog_df.shape[0])
print('immediate events after 2pm:')
print(elog_df[elog_df['Start Time Float'] >= 14.0].shape[0])
print(elog_df[elog_df['Start Time Float'] >= 14.0].shape[0]/elog_df.shape[0])
print('immediate events after 10am:')
print(elog_df[elog_df['Start Time Float'] >= 10.0].shape[0])
print(elog_df[elog_df['Start Time Float'] >= 10.0].shape[0]/elog_df.shape[0])


display(elog_df[elog_df['Start Time Float'] >= 14.0])
# Out:
# total immediate events:
# 56
# immediate events after 2pm:
# 48
# 0.8571428571428571
# immediate events after 10am:
# 53
# 0.9464285714285714
#     Event Date Administrator Program Start Time End Time Event Duration  \
# 171 2016-07-15    Con Edison    DLRP      14:00    20:00           6:00
# 173 2016-07-22    Con Edison    DLRP      17:00    23:00           6:00
# 174 2016-07-23    Con Edison    DLRP      22:00     0:00           2:00
# 215 2016-08-12    Con Edison    DLRP      17:00    22:00           5:00
# 216 2016-08-12    Con Edison    DLRP      16:00     0:00           8:00
# 231 2016-08-13    Con Edison    DLRP      14:00    22:00           8:00
# 232 2016-08-13    Con Edison    DLRP      14:00    22:00           8:00
# 265 2017-06-19    Con Edison    DLRP      16:00    22:00           6:00
# 266 2017-06-19    Con Edison    DLRP      16:00    22:00           6:00
# 296 2018-05-03    Con Edison    DLRP      16:00    22:00           6:00
# 305 2018-06-18    Con Edison    DLRP      17:00    23:00           6:00
# 420 2019-07-17    Con Edison    DLRP      17:00    23:00           6:00
# 421 2019-07-17    Con Edison    DLRP      17:00    23:00           6:00
# 483 2019-07-22    Con Edison    DLRP      16:00    22:00           6:00
# 508 2019-08-22    Con Edison    DLRP      14:00    20:00           6:00
# 612 2021-06-29    Con Edison    DLRP      19:00     0:00           5:00
# 613 2021-06-29    Con Edison    DLRP      20:00     0:00           4:00
# 614 2021-06-29    Con Edison    DLRP      21:00     0:00           3:00
# 641 2021-06-30    Con Edison    DLRP      21:00     0:00           3:00
# 642 2021-06-30    Con Edison    DLRP      21:00     0:00           3:00
# 659 2021-08-12    Con Edison    DLRP      16:00    22:00           6:00
# 674 2021-08-25    Con Edison    DLRP      21:00     0:00           3:00
# 679 2021-09-02    Con Edison    DLRP      14:00    22:00           8:00
# 683 2022-05-31    Con Edison    DLRP      16:00    22:00           6:00
# 684 2022-05-31    Con Edison    DLRP      18:00    23:00           5:00
# 686 2022-07-18    Con Edison    DLRP      18:00     0:00           6:00
# 700 2022-07-20    Con Edison    DLRP      17:30    23:30           6:00
# 701 2022-07-20    Con Edison    DLRP      19:00     0:00           6:00
# 715 2022-07-21    Con Edison    DLRP      16:00    22:00           6:00
# 768 2022-08-08    Con Edison    DLRP      15:00    21:00           6:00
# 784 2022-08-09    Con Edison    DLRP      19:00     0:00           5:00
# 785 2022-08-09    Con Edison    DLRP      19:00     0:00           5:00
# 792 2023-07-05    Con Edison    DLRP      18:30    23:30           5:00
# 798 2023-07-11    Con Edison    DLRP      16:30    22:30           6:00
# 818 2023-07-28    Con Edison    DLRP      17:00    23:00           6:00
# 819 2023-07-28    Con Edison    DLRP      18:00     0:00           6:00
# 824 2023-07-29    Con Edison    DLRP      15:30    21:30           6:00
# 834 2023-09-05    Con Edison    DLRP      16:30    23:30           7:00
# 840 2023-09-06    Con Edison    DLRP      18:00     0:00           6:00
# 855 2023-09-07    Con Edison    DLRP      16:00    22:00           6:00
# 856 2023-09-08    Con Edison    DLRP      15:30    21:30           6:00
# 867 2024-07-10    Con Edison    DLRP      21:00     0:00           3:00
# 884 2024-07-15    Con Edison    DLRP      16:30    22:30           6:00
# 924 2024-08-01    Con Edison    DLRP      20:30    23:30           3:00
# 928 2024-08-02    Con Edison    DLRP      20:00     0:00           4:00
# 932 2024-08-03    Con Edison    DLRP      15:00    21:00           6:00
# 933 2024-08-03    Con Edison    DLRP      15:30    21:30           6:00
# 934 2024-08-03    Con Edison    DLRP      17:00    23:00           6:00
#
#           Zone/Network Event/Test      Event Type           DT Format  \
# 171        Fresh Kills      Event       Immediate 1900-01-01 14:00:00
# 173          Fox Hills      Event       Immediate 1900-01-01 17:00:00
# 174            Triboro      Event       Immediate 1900-01-01 22:00:00
# 215          Fox Hills      Event       Immediate 1900-01-01 17:00:00
# 216        Fresh Kills      Event       Immediate 1900-01-01 16:00:00
# 231          Fox Hills      Event       Immediate 1900-01-01 14:00:00
# 232        Fresh Kills      Event       Immediate 1900-01-01 14:00:00
# 265       Williamsburg      Event       Immediate 1900-01-01 16:00:00
# 266      Prospect Park      Event       Immediate 1900-01-01 16:00:00
# 296          Fox Hills      Event       Immediate 1900-01-01 16:00:00
# 305          Fox Hills      Event       Immediate 1900-01-01 17:00:00
# 420          Fox Hills      Event       Immediate 1900-01-01 17:00:00
# 421        Willowbrook      Event       Immediate 1900-01-01 17:00:00
# 483           Flatbush      Event       Immediate 1900-01-01 16:00:00
# 508          Bay Ridge      Event       Immediate 1900-01-01 14:00:00
# 612          Yorkville      Event       Immediate 1900-01-01 19:00:00
# 613            Maspeth      Event       Immediate 1900-01-01 20:00:00
# 614       Central Park      Event       Immediate 1900-01-01 21:00:00
# 641           Flatbush      Event       Immediate 1900-01-01 21:00:00
# 642       Williamsburg      Event       Immediate 1900-01-01 21:00:00
# 659          Rego Park      Event       Immediate 1900-01-01 16:00:00
# 674        Fresh Kills      Event       Immediate 1900-01-01 21:00:00
# 679          Yorkville      Event       Immediate 1900-01-01 14:00:00
# 683        Fresh Kills      Event       Immediate 1900-01-01 16:00:00
# 684          Fox Hills      Event       Immediate 1900-01-01 18:00:00
# 686          City Hall      Event       Immediate 1900-01-01 18:00:00
# 700        Fresh Kills      Event       Immediate 1900-01-01 17:30:00
# 701      Ossining West      Event       Immediate 1900-01-01 19:00:00
# 715            Jamaica      Event       Immediate 1900-01-01 16:00:00
# 768      Ossining West      Event       Immediate 1900-01-01 15:00:00
# 784    Southeast Bronx      Event       Immediate 1900-01-01 19:00:00
# 785       Cedar Street      Event       Immediate 1900-01-01 19:00:00
# 792          Fox Hills      Event       Immediate 1900-01-01 18:30:00
# 798      Central Bronx      Event       Immediate 1900-01-01 16:30:00
# 818  Washington Street      Event       Immediate 1900-01-01 17:00:00
# 819     Elmsford No. 2      Event       Immediate 1900-01-01 18:00:00
# 824    Jackson Heights      Event       Immediate 1900-01-01 15:30:00
# 834        Fresh Kills      Event       Immediate 1900-01-01 16:30:00
# 840        Fresh Kills      Event       Immediate 1900-01-01 18:00:00
# 855          Rego Park      Event       Immediate 1900-01-01 16:00:00
# 856        Fresh Kills      Event       Immediate 1900-01-01 15:30:00
# 867     Elmsford No. 2      Event  DLRP Immediate 1900-01-01 21:00:00
# 884     Elmsford No. 2      Event  DLRP Immediate 1900-01-01 16:30:00
# 924       White Plains      Event  DLRP Immediate 1900-01-01 20:30:00
# 928        Fresh Kills      Event  DLRP Immediate 1900-01-01 20:00:00
# 932            Fordham      Event  DLRP Immediate 1900-01-01 15:00:00
# 933      Fordham SC 11      Event  DLRP Immediate 1900-01-01 15:30:00
# 934     Elmsford No. 2      Event  DLRP Immediate 1900-01-01 17:00:00
#
#      Start Time Float
# 171              14.0
# 173              17.0
# 174              22.0
# 215              17.0
# 216              16.0
# 231              14.0
# 232              14.0
# 265              16.0
# 266              16.0
# 296              16.0
# 305              17.0
# 420              17.0
# 421              17.0
# 483              16.0
# 508              14.0
# 612              19.0
# 613              20.0
# 614              21.0
# 641              21.0
# 642              21.0
# 659              16.0
# 674              21.0
# 679              14.0
# 683              16.0
# 684              18.0
# 686              18.0
# 700              17.5
# 701              19.0
# 715              16.0
# 768              15.0
# 784              19.0
# 785              19.0
# 792              18.5
# 798              16.5
# 818              17.0
# 819              18.0
# 824              15.5
# 834              16.5
# 840              18.0
# 855              16.0
# 856              15.5
# 867              21.0
# 884              16.5
# 924              20.5
# 928              20.0
# 932              15.0
# 933              15.5
# 934              17.0

# %%
plt.figure(figsize=(14,7)) # Make it 14x7 inch
plt.hist(elog_df['Start Time Float'], bins=32, facecolor = '#2ab0ff', edgecolor='#169acf', linewidth=0.5)
plt.title('Immediate Events by Start Time') 
plt.xlabel('Start Times') 
#plt.xticks(elog_df['Start Time Float'])
plt.ylabel('Number of Immediate Events 2016-2024') 
plt.show()

# %%
#events by month
elog_df['Month'] = elog_df['Event Date'].dt.month
#elog_df.head()

plt.figure(figsize=(14,7)) # Make it 14x7 inch
plt.hist(elog_df['Month'], bins=5, facecolor = '#2ab0ff', edgecolor='#169acf', linewidth=0.5)
plt.title('Immediate Events by Month') 
plt.xlabel('Months') 
plt.ylabel('Number of Immediate Events 2016-2023') 
plt.show()
# Out:
# C:\Users\alexn\AppData\Local\Temp\ipykernel_56540\182982057.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elog_df['Month'] = elog_df['Event Date'].dt.month

# %%
#years in which immediate events occurred

#the average time off from the scheduled time
networks_df['immediate years'] = pd.Series()
#the number of immediate events
networks_df['immediate count'] = 0

iE = {}
for r in range(elog_df.shape[0]):
    n = elog_df.iloc[r]['Zone/Network'].lower()
    #s = float(elog_df.iloc[r]['Start Time Float'])
    #nS = networks_df[networks_df['network']==n]['start time float'].iloc[0]#.loc['start time float']
    #v = abs(s - nS)
    eY = elog_df['Event Date'].iloc[r].year
    networks_df.loc[networks_df['network']==n,'immediate count']= networks_df.loc[networks_df['network']==n,'immediate count'] + 1
    if n in iE.keys():
        iE[n].append(eY)
    else:
        iE[n] = [eY]

for n in iE.keys():
    #get unique years
    u = []
    [u.append(x) for x in iE[n] if x not in u]
    networks_df.loc[networks_df['network']==n,'immediate years']= len(u)

print(iE)
networks_df[networks_df['immediate count'] > 0]
# Out:
# {'fresh kills': [2016, 2016, 2016, 2021, 2022, 2022, 2023, 2023, 2023, 2024], 'fox hills': [2016, 2016, 2016, 2018, 2018, 2019, 2022, 2023, 2023], 'triboro': [2016], 'williamsburg': [2017, 2021], 'prospect park': [2017], 'willowbrook': [2019], 'flatbush': [2019, 2021], 'bay ridge': [2019], 'southeast bronx': [2020, 2022], 'yorkville': [2021, 2021], 'maspeth': [2021], 'central park': [2021], 'jamaica': [2021, 2022], 'rego park': [2021, 2022, 2023], 'city hall': [2022], 'ossining west': [2022, 2022], 'ridgewood': [2022], 'central bronx': [2022, 2023], 'cedar street': [2022], 'washington street': [2023], 'elmsford no. 2': [2023, 2024, 2024, 2024], 'jackson heights': [2023], 'granite hill': [2024, 2024], 'white plains': [2024], 'fordham': [2024], 'fordham sc 11': [2024]}
#           borough            network start time end time  tier  \
# 0           bronx      central bronx      16:00    20:00     2
# 1           bronx            fordham      16:00    20:00     2
# 4           bronx    southeast bronx      16:00    20:00     1
# 6        brooklyn          bay ridge      14:00    18:00     1
# 10       brooklyn           flatbush      16:00    20:00     1
# 13       brooklyn      prospect park      16:00    20:00     1
# 14       brooklyn          ridgewood      16:00    20:00     2
# 16       brooklyn       williamsburg      16:00    20:00     2
# 21      manhattan       central park      16:00    20:00     1
# 23      manhattan          city hall      11:00    15:00     1
# 51      manhattan            triboro      14:00    18:00     1
# 54      manhattan          yorkville      14:00    18:00     1
# 57         queens    jackson heights      16:00    20:00     2
# 58         queens            jamaica      16:00    20:00     2
# 60         queens            maspeth      16:00    20:00     1
# 61         queens          rego park      16:00    20:00     1
# 64  staten island          fox hills      16:00    20:00     1
# 65  staten island        fresh kills      16:00    20:00     1
# 67  staten island        willowbrook      16:00    20:00     1
# 70    westchester       cedar street      16:00    20:00     1
# 71    westchester     elmsford no. 2      16:00    20:00     1
# 72    westchester       granite hill      16:00    20:00     1
# 77    westchester  washington street      16:00    20:00     1
# 78    westchester       white plains      14:00    18:00     1
# 81    westchester      ossining west      16:00    20:00     1
#
#    immediate years  immediate count
# 0                2                2
# 1                1                1
# 4                2                2
# 6                1                1
# 10               2                2
# 13               1                1
# 14               1                1
# 16               2                2
# 21               1                1
# 23               1                1
# 51               1                1
# 54               1                2
# 57               1                1
# 58               2                2
# 60               1                1
# 61               3                3
# 64               5                9
# 65               5               10
# 67               1                1
# 70               1                1
# 71               2                4
# 72               1                2
# 77               1                1
# 78               1                1
# 81               1                2

# %%
iNetworks = networks_df[networks_df['immediate count'] > 0]
print(iNetworks.shape[0])
print(iNetworks['immediate years'].mean())
print('1 year: ' + str(iNetworks[iNetworks['immediate years']==1].shape[0]))
print('2 year: ' + str(iNetworks[iNetworks['immediate years']==2].shape[0]))
print('3 year: ' + str(iNetworks[iNetworks['immediate years']==3].shape[0]))
print('4 year: ' + str(iNetworks[iNetworks['immediate years']==4].shape[0]))
print('5 year: ' + str(iNetworks[iNetworks['immediate years']==5].shape[0]))
# Out:
# 25
# 1.64
# 1 year: 16
# 2 year: 6
# 3 year: 1
# 4 year: 0
# 5 year: 2

# %% [markdown]
# ### Analysis of Contingent Events

# %%
#contingency events
#filter out non DLRP events
clog_df = flog_df[flog_df['Program'].isin(['DLRP'])]

#filter to only contingency evvnets
clog_df = clog_df[(clog_df['Event Type']=='Contingency')| (clog_df['Event Type']=='DLRP Contingency')]
clog_df['Zone/Network'].unique()
# Out:
# array(['Riverdale', 'Crown Heights', 'Ridgewood', 'Richmond Hill',
#        'Sheepshead Bay', 'Williamsburg', 'Prospect Park', 'Central Park',
#        'Madison Square', 'Cooper Square', 'Brownsville*', 'All^',
#        'Flatbush', 'Willowbrook', 'Wainwright', 'Rego Park',
#        'Non-Manhattan**', 'Maspeth', 'Non-Manhattan***', 'Borough Hall',
#        'Bay Ridge', 'Fresh Kills', 'Park Slope', 'Fox Hills', 'Jamaica'],
#       dtype=object)

# %%
uC = getUnique(clog_df['Zone/Network'].unique())
print(uC)
print('number of networks with contingency events:')
#number of networks with contingency events
print(len(uC))
#percentage with contingency events
print('percentage with contingency events:')
print(len(uC)/networks_df.shape[0])
#uC
# Out:
# ['riverdale', 'crown heights', 'ridgewood', 'richmond hill', 'sheepshead bay', 'williamsburg', 'prospect park', 'central park', 'madison square', 'cooper square', 'central bronx', 'fordham', 'northeast bronx', 'southeast bronx', 'west bronx', 'bay ridge', 'brighton beach', 'flatbush', 'ocean parkway', 'park slope', 'borden', 'flushing', 'jackson heights', 'jamaica', 'long island city', 'maspeth', 'rego park', 'sunnyside', 'fox hills', 'fresh kills', 'wainwright', 'willowbrook', 'woodrow', 'buchanan', 'cedar street', 'elmsford 2', 'granite hill', 'grasslands', 'harrison', 'millwood west', 'mohansic', 'washington street', 'white plains', 'pleasantville', 'rockview', 'ossining west', 'washington heights', 'borough hall']
# number of networks with contingency events:
# 48
# percentage with contingency events:
# 0.5783132530120482

# %%
#this was the inform the getUnique function conditions - NOT necessary at this point
#display(clog_df[clog_df['Zone/Network'].isin(['All','All^','Non-Manhattan**','Non-Manhattan***','Brownsville*'])])

# %%
display(clog_df)
# Out:
#     Event Date Administrator Program Start Time End Time Event Duration  \
# 176 2016-07-24    Con Edison    DLRP       6:00    10:00           4:00
# 195 2016-08-11    Con Edison    DLRP      14:00    20:00           6:00
# 196 2016-08-11    Con Edison    DLRP      14:00    20:00           6:00
# 197 2016-08-11    Con Edison    DLRP      14:00    20:00           6:00
# 201 2016-08-12    Con Edison    DLRP      14:00    20:00           6:00
# 202 2016-08-12    Con Edison    DLRP      14:00    20:00           6:00
# 203 2016-08-12    Con Edison    DLRP      14:00    20:00           6:00
# 217 2016-08-13    Con Edison    DLRP      15:00    21:00           6:00
# 218 2016-08-13    Con Edison    DLRP      15:00    21:00           6:00
# 219 2016-08-13    Con Edison    DLRP      15:00    21:00           6:00
# 220 2016-08-13    Con Edison    DLRP      16:00    22:00           6:00
# 233 2016-08-14    Con Edison    DLRP      16:00    22:00           6:00
# 234 2016-08-14    Con Edison    DLRP      16:00    22:00           6:00
# 235 2016-08-14    Con Edison    DLRP      16:00    22:00           6:00
# 242 2016-08-15    Con Edison    DLRP      15:00    21:00           6:00
# 243 2016-08-15    Con Edison    DLRP      15:00    21:00           6:00
# 244 2016-08-15    Con Edison    DLRP      15:00    21:00           6:00
# 255 2016-08-16    Con Edison    DLRP      16:00    22:00           6:00
# 256 2016-08-16    Con Edison    DLRP      16:00    22:00           6:00
# 257 2016-08-16    Con Edison    DLRP      16:00    22:00           6:00
# 261 2017-06-12    Con Edison    DLRP      15:00    21:00           6:00
# 262 2017-06-12    Con Edison    DLRP      15:00    21:00           6:00
# 263 2017-06-13    Con Edison    DLRP      15:00    21:00           6:00
# 264 2017-06-13    Con Edison    DLRP      15:00    21:00           6:00
# 381 2018-08-29    Con Edison    DLRP      14:00    20:00           6:00
# 390 2018-08-30    Con Edison    DLRP      13:00    19:00           6:00
# 414 2019-06-27    Con Edison    DLRP      14:00    20:00           6:00
# 417 2019-07-17    Con Edison    DLRP      18:00     0:00           6:00
# 433 2019-07-19    Con Edison    DLRP      18:00     0:00           6:00
# 440 2019-07-20    Con Edison    DLRP      11:00    15:00           4:00
# 441 2019-07-20    Con Edison    DLRP      14:00    18:00           4:00
# 442 2019-07-20    Con Edison    DLRP      16:00    20:00           4:00
# 443 2019-07-20    Con Edison    DLRP      19:00    23:00           4:00
# 455 2019-07-20    Con Edison    DLRP      18:00     0:00           6:00
# 462 2019-07-21    Con Edison    DLRP      11:00    15:00           4:00
# 463 2019-07-21    Con Edison    DLRP      14:00    18:00           4:00
# 464 2019-07-21    Con Edison    DLRP      16:00    20:00           4:00
# 465 2019-07-21    Con Edison    DLRP      19:00    23:00           4:00
# 477 2019-07-21    Con Edison    DLRP      18:00     0:00           6:00
# 480 2019-07-22    Con Edison    DLRP      18:00     0:00           6:00
# 486 2019-07-30    Con Edison    DLRP      16:00    22:00           6:00
# 487 2019-07-30    Con Edison    DLRP      16:00    22:00           6:00
# 488 2019-07-30    Con Edison    DLRP      16:00    22:00           6:00
# 516 2020-06-22    Con Edison    DLRP      19:00     0:00           5:00
# 519 2020-06-25    Con Edison    DLRP      16:00    22:00           6:00
# 522 2020-06-26    Con Edison    DLRP      16:00    22:00           6:00
# 526 2020-06-27    Con Edison    DLRP      18:00    22:00           4:00
# 530 2020-06-28    Con Edison    DLRP      17:00    23:00           6:00
# 534 2020-06-29    Con Edison    DLRP      16:00    22:00           6:00
# 538 2020-06-30    Con Edison    DLRP      16:00    22:00           6:00
# 540 2020-07-01    Con Edison    DLRP      16:00    22:00           6:00
# 542 2020-07-02    Con Edison    DLRP      16:00    22:00           6:00
# 547 2020-07-06    Con Edison    DLRP      16:00    22:00           6:00
# 553 2020-07-07    Con Edison    DLRP      16:00    22:00           6:00
# 558 2020-07-20    Con Edison    DLRP      16:00    22:00           6:00
# 561 2020-07-21    Con Edison    DLRP      16:00    22:00           6:00
# 562 2020-07-21    Con Edison    DLRP      16:00    22:00           6:00
# 573 2020-07-27    Con Edison    DLRP      16:00    22:00           6:00
# 579 2020-07-28    Con Edison    DLRP      16:00    22:00           6:00
# 583 2020-07-29    Con Edison    DLRP      16:00    22:00           6:00
# 589 2020-07-30    Con Edison    DLRP      13:00     0:00          11:00
# 637 2021-06-30    Con Edison    DLRP      14:00    19:00           5:00
# 638 2021-06-30    Con Edison    DLRP      14:00    19:00           5:00
# 640 2021-06-30    Con Edison    DLRP      18:00     0:00           6:00
# 643 2021-07-16    Con Edison    DLRP      16:00    22:00           6:00
# 660 2021-08-12    Con Edison    DLRP      20:00     0:00           4:00
# 669 2021-08-13    Con Edison    DLRP      20:00     0:00           4:00
# 675 2021-08-27    Con Edison    DLRP      16:00    22:00           6:00
# 721 2022-07-24    Con Edison    DLRP      16:00    20:00           4:00
# 727 2022-07-25    Con Edison    DLRP      14:00    18:00           4:00
# 794 2023-07-06    Con Edison    DLRP      10:00    16:00           6:00
# 796 2023-07-06    Con Edison    DLRP      16:00    23:59           8:00
#
#          Zone/Network Event/Test   Event Type
# 176         Riverdale      Event  Contingency
# 195     Crown Heights      Event  Contingency
# 196         Ridgewood      Event  Contingency
# 197     Richmond Hill      Event  Contingency
# 201     Crown Heights      Event  Contingency
# 202         Ridgewood      Event  Contingency
# 203     Richmond Hill      Event  Contingency
# 217     Crown Heights      Event  Contingency
# 218         Ridgewood      Event  Contingency
# 219     Richmond Hill      Event  Contingency
# 220    Sheepshead Bay      Event  Contingency
# 233     Crown Heights      Event  Contingency
# 234         Ridgewood      Event  Contingency
# 235     Richmond Hill      Event  Contingency
# 242     Crown Heights      Event  Contingency
# 243         Ridgewood      Event  Contingency
# 244     Richmond Hill      Event  Contingency
# 255     Crown Heights      Event  Contingency
# 256         Ridgewood      Event  Contingency
# 257     Richmond Hill      Event  Contingency
# 261      Williamsburg      Event  Contingency
# 262     Prospect Park      Event  Contingency
# 263      Williamsburg      Event  Contingency
# 264     Prospect Park      Event  Contingency
# 381      Central Park      Event  Contingency
# 390    Madison Square      Event  Contingency
# 414     Cooper Square      Event  Contingency
# 417      Brownsville*      Event  Contingency
# 433      Brownsville*      Event  Contingency
# 440              All^      Event  Contingency
# 441              All^      Event  Contingency
# 442              All^      Event  Contingency
# 443              All^      Event  Contingency
# 455      Brownsville*      Event  Contingency
# 462              All^      Event  Contingency
# 463              All^      Event  Contingency
# 464              All^      Event  Contingency
# 465              All^      Event  Contingency
# 477      Brownsville*      Event  Contingency
# 480      Brownsville*      Event  Contingency
# 486          Flatbush      Event  Contingency
# 487       Willowbrook      Event  Contingency
# 488        Wainwright      Event  Contingency
# 516         Rego Park      Event  Contingency
# 519      Brownsville*      Event  Contingency
# 522      Brownsville*      Event  Contingency
# 526      Brownsville*      Event  Contingency
# 530      Brownsville*      Event  Contingency
# 534      Brownsville*      Event  Contingency
# 538      Brownsville*      Event  Contingency
# 540      Brownsville*      Event  Contingency
# 542      Brownsville*      Event  Contingency
# 547      Brownsville*      Event  Contingency
# 553      Brownsville*      Event  Contingency
# 558   Non-Manhattan**      Event  Contingency
# 561           Maspeth      Event  Contingency
# 562    Sheepshead Bay      Event  Contingency
# 573  Non-Manhattan***      Event  Contingency
# 579  Non-Manhattan***      Event  Contingency
# 583      Borough Hall      Event  Contingency
# 589         Bay Ridge      Event  Contingency
# 637     Crown Heights      Event  Contingency
# 638         Ridgewood      Event  Contingency
# 640         Bay Ridge      Event  Contingency
# 643     Crown Heights      Event  Contingency
# 660       Fresh Kills      Event  Contingency
# 669       Fresh Kills      Event  Contingency
# 675     Cooper Square      Event  Contingency
# 721          Flatbush      Event  Contingency
# 727        Park Slope      Event  Contingency
# 794         Fox Hills      Event  Contingency
# 796           Jamaica      Event  Contingency

# %%
def eventCount(d):
    countDict = {}
    yearDict = {}
    
    for n in allN:
        countDict[n] = 0
        yearDict[n] = []
    #print(countDict)
    #print(d['Zone/Network'])
    #for r in d:
    for index, r in d.iterrows():
#     print(row['c1'], row['c2'])
        z = r['Zone/Network']
    
        if z == 'ossining west':
            print('O')
        y = r['Event Date'].year
        #print(z)
        if z not in ['All','All^','Non-Manhattan**','Non-Manhattan***','Brownsville*']:
            countDict[z.lower()]=countDict[z.lower()]+1
            yearDict[z.lower()].append(y)
        elif z == 'All':
            for n in allN:
                countDict[n]=countDict[n]+1
                yearDict[n].append(y)
        elif z == 'Brownsville*':
            for b in brownsvilleNetworks :
                countDict[b]=countDict[b]+1
                yearDict[b].append(y)
        elif z == 'All^':
            #in 2019 All^ exlcludes Manhattan, Borough Hall, and Brownsville
            #in 2020 All^ excludes Brownsville Networks but this is not present in the filtered data
            #loop through all networks
            for nn in allN:
                #exclude browseville networks
                if nn not in brownsvilleNetworks:
                    #exclude manhattan networks
                    if nn not in mN:
                        if nn != 'Borough Hall':
                            countDict[nn.lower()]=countDict[nn.lower()]+1
                            yearDict[nn.lower()].append(y)
        elif z == 'Non-Manhattan**':
            #in 2019 Non-Manhattan** excludes Brownsville (BQDM) networks but this is not present in the filtered data
            #in 2020 Non-Manhattan** excludes Borough Hall
            #loop through all non-manhattan networks
            for nn in nM:
                if nn != 'Borough Hall':
                    countDict[nn.lower()]=countDict[nn.lower()]+1
                    yearDict[nn.lower()].append(y)
        elif z == 'Non-Manhattan***':
            #in 2020 Non-Manhattan*** includes Washington Heights in Manhattan. Excludes Borough Hall
            for nn in nM:
                    if nn != 'Borough Hall':
                        countDict[nn.lower()]=countDict[nn.lower()]+1
                        yearDict[nn.lower()].append(y)
            countDict['washington heights']=countDict['washington heights']+1
            yearDict['washington heights'].append(y)

        countArrayD = []
        
    for n in allN:
        countArrayD.append({'name':n, 'count': countDict[n],'years': yearDict[n]})
    return countArrayD

# %%
#network event frequency

#drop duplicates for 'All^' events
prevAllDate=0
dropList = []
for a in range(clog_df.shape[0]):
    if clog_df.iloc[a]['Zone/Network']=='All^':
        if clog_df.iloc[a]['Event Date'] == prevAllDate:
            di =  clog_df.iloc[a]
            dropList.append(clog_df.iloc[a].name)
        else:
            prevAllDate = clog_df.iloc[a]['Event Date']

print(dropList)
clog_df.drop(dropList, inplace=True)
#clog_df[clog_df['Zone/Network'].isin(['All','All^','Non-Manhattan**','Non-Manhattan***','Brownsville*'])]

dlrpFreq_df = pd.DataFrame.from_dict(eventCount(clog_df))

#filter out networks without events
dlrpFreq_df = dlrpFreq_df[dlrpFreq_df['count'] > 0]

print(dlrpFreq_df.shape[0])

#get unique year counts
yC = []
for i, r in dlrpFreq_df.iterrows():
    yC.append(len(list(set(r['years']))))
    
dlrpFreq_df['unique years'] = yC

dlrpFreq_df
# Out:
# [np.int64(441), np.int64(442), np.int64(443), np.int64(463), np.int64(464), np.int64(465)]
# 48
#                   name  count  \
# 0        central bronx      5
# 1              fordham      5
# 2      northeast bronx      5
# 3            riverdale      6
# 4      southeast bronx      5
# 5           west bronx      5
# 6            bay ridge      7
# 7         borough hall      6
# 8       brighton beach      5
# 9        crown heights     26
# 10            flatbush      7
# 11       ocean parkway      5
# 12          park slope      6
# 13       prospect park      7
# 14           ridgewood     25
# 15      sheepshead bay      7
# 16        williamsburg      7
# 21        central park      1
# 25       cooper square      2
# 41      madison square      1
# 54  washington heights      2
# 56              borden      5
# 57            flushing      5
# 58     jackson heights      5
# 59             jamaica      6
# 60    long island city      5
# 61             maspeth      6
# 62           rego park      6
# 63       richmond hill     24
# 64           sunnyside      5
# 65           fox hills      6
# 66         fresh kills      7
# 67          wainwright      6
# 68         willowbrook      6
# 69             woodrow      5
# 70            buchanan      5
# 71        cedar street      5
# 72          elmsford 2      5
# 73        granite hill      5
# 74          grasslands      5
# 75            harrison      5
# 76       millwood west      5
# 77            mohansic      5
# 78   washington street      5
# 79        white plains      5
# 80       pleasantville      5
# 81            rockview      5
# 82       ossining west      5
#
#                                                 years  unique years
# 0                      [2019, 2019, 2020, 2020, 2020]             2
# 1                      [2019, 2019, 2020, 2020, 2020]             2
# 2                      [2019, 2019, 2020, 2020, 2020]             2
# 3                [2016, 2019, 2019, 2020, 2020, 2020]             3
# 4                      [2019, 2019, 2020, 2020, 2020]             2
# 5                      [2019, 2019, 2020, 2020, 2020]             2
# 6          [2019, 2019, 2020, 2020, 2020, 2020, 2021]             3
# 7                [2019, 2019, 2020, 2020, 2020, 2020]             2
# 8                      [2019, 2019, 2020, 2020, 2020]             2
# 9   [2016, 2016, 2016, 2016, 2016, 2016, 2019, 201...             4
# 10         [2019, 2019, 2019, 2020, 2020, 2020, 2022]             3
# 11                     [2019, 2019, 2020, 2020, 2020]             2
# 12               [2019, 2019, 2020, 2020, 2020, 2022]             3
# 13         [2017, 2017, 2019, 2019, 2020, 2020, 2020]             3
# 14  [2016, 2016, 2016, 2016, 2016, 2016, 2019, 201...             4
# 15         [2016, 2019, 2019, 2020, 2020, 2020, 2020]             3
# 16         [2017, 2017, 2019, 2019, 2020, 2020, 2020]             3
# 21                                             [2018]             1
# 25                                       [2019, 2021]             2
# 41                                             [2018]             1
# 54                                       [2020, 2020]             1
# 56                     [2019, 2019, 2020, 2020, 2020]             2
# 57                     [2019, 2019, 2020, 2020, 2020]             2
# 58                     [2019, 2019, 2020, 2020, 2020]             2
# 59               [2019, 2019, 2020, 2020, 2020, 2023]             3
# 60                     [2019, 2019, 2020, 2020, 2020]             2
# 61               [2019, 2019, 2020, 2020, 2020, 2020]             2
# 62               [2019, 2019, 2020, 2020, 2020, 2020]             2
# 63  [2016, 2016, 2016, 2016, 2016, 2016, 2019, 201...             3
# 64                     [2019, 2019, 2020, 2020, 2020]             2
# 65               [2019, 2019, 2020, 2020, 2020, 2023]             3
# 66         [2019, 2019, 2020, 2020, 2020, 2021, 2021]             3
# 67               [2019, 2019, 2019, 2020, 2020, 2020]             2
# 68               [2019, 2019, 2019, 2020, 2020, 2020]             2
# 69                     [2019, 2019, 2020, 2020, 2020]             2
# 70                     [2019, 2019, 2020, 2020, 2020]             2
# 71                     [2019, 2019, 2020, 2020, 2020]             2
# 72                     [2019, 2019, 2020, 2020, 2020]             2
# 73                     [2019, 2019, 2020, 2020, 2020]             2
# 74                     [2019, 2019, 2020, 2020, 2020]             2
# 75                     [2019, 2019, 2020, 2020, 2020]             2
# 76                     [2019, 2019, 2020, 2020, 2020]             2
# 77                     [2019, 2019, 2020, 2020, 2020]             2
# 78                     [2019, 2019, 2020, 2020, 2020]             2
# 79                     [2019, 2019, 2020, 2020, 2020]             2
# 80                     [2019, 2019, 2020, 2020, 2020]             2
# 81                     [2019, 2019, 2020, 2020, 2020]             2
# 82                     [2019, 2019, 2020, 2020, 2020]             2

# %%
ax = dlrpFreq_df['count'].plot(kind='bar', title ="Networks by Contingency Frequency", figsize=(15, 10), legend=True)
ax.set_xlabel("Networks")
ax.set_xticklabels(list(dlrpFreq_df['name']))
ax.set_ylabel("Count")
plt.show()

# %%
print('amount of networks with 2 or fewer contingency events ever')
print(dlrpFreq_df[dlrpFreq_df['unique years'] <= 2].shape[0])
print(dlrpFreq_df[dlrpFreq_df['unique years'] <= 2].shape[0]/networks_df.shape[0])

ax = dlrpFreq_df['unique years'].plot(kind='bar', title ="Networks by Unique Years Contingency Events Occur", figsize=(15, 10), legend=True)
ax.set_xlabel("Networks")
ax.set_xticklabels(list(dlrpFreq_df['name']))
ax.set_ylabel("Amount of Years")
plt.show()
# Out:
# amount of networks with 2 or fewer contingency events ever
# 35
# 0.42168674698795183

# %%
# # Histogram of networks with DLRP events
# plt.figure(figsize=(14,7)) # Make it 14x7 inch
# plt.style.use('seaborn-whitegrid') # nice and clean grid
# plt.hist(clog_df['Zone/Network'], bins=len(clog_df['Zone/Network'].unique()), facecolor = '#2ab0ff', edgecolor='#169acf', linewidth=0.5)
# plt.title('Contingency Events by Network') 
# plt.xlabel('Networks') 
# plt.xticks(rotation='vertical')
# plt.ylabel('Number of Contingent Events 2016-2023') 
# plt.show()

# %%
#events by month
clog_df['Month'] = clog_df['Event Date'].dt.month
#elog_df.head()

plt.figure(figsize=(14,7)) # Make it 14x7 inch
plt.hist(clog_df['Month'], bins=12, facecolor = '#2ab0ff', edgecolor='#169acf', linewidth=0.5)
plt.title('Contingent Events by Month') 
plt.xlabel('Months') 
plt.ylabel('Number of Immediate Events 2016-2023') 
plt.show()

# %%
#networks with contingency events NOT in July
set(list(clog_df[clog_df['Month']!=7]['Zone/Network']))
len(list(set(list(clog_df[clog_df['Month']!=7]['Zone/Network']))))
# Out:
# 13

# %%
plt.figure(figsize=(14,7)) # Make it 14x7 inch
plt.hist(clog_df['Event Date'].dt.year, bins=7, facecolor = '#2ab0ff', edgecolor='#169acf', linewidth=0.5)
plt.title('Contingency Events by Year') 
plt.xlabel('Networks') 
#plt.xticks(rotation='vertical')
plt.ylabel('Number of Contingent Events 2016-2023') 
plt.show()

# %%
#get the individual network contingency events
#iclog_df = clog_df[~clog_df['Zone/Network'].isin(['All','All^','Non-Manhattan**','Non-Manhattan***','Brownsville*'])]
#iclog_df

# %%
#convert start times to datetime format
clog_df['DT Format'] = pd.to_datetime(clog_df['Start Time'], format='%H:%M')
clog_df['Start Time Float'] = clog_df['DT Format'].dt.hour + (clog_df['DT Format'].dt.minute/60)
#convert to float
clog_df['Start Time Float'].apply(lambda x: float(x))

plt.figure(figsize=(14,7)) # Make it 14x7 inch
plt.hist(clog_df['Start Time'], bins=24, facecolor = '#2ab0ff', edgecolor='#169acf', linewidth=0.5)
plt.title('Contingency Events by Start Time') 
plt.xlabel('Networks') 
#plt.xticks(rotation='vertical')
plt.ylabel('Number of Contingent Events 2016-2023') 
plt.show()

# %%
clog_df[clog_df['Start Time']=='6:00']
# Out:
#     Event Date Administrator Program Start Time End Time Event Duration  \
# 176 2016-07-24    Con Edison    DLRP       6:00    10:00           4:00
#
#     Zone/Network Event/Test   Event Type  Month           DT Format  \
# 176    Riverdale      Event  Contingency      7 1900-01-01 06:00:00
#
#      Start Time Float
# 176               6.0

# %% [markdown]
# ## CSRP Analysis

# %%
#filter out non CSRP events
rlog_df = flog_df[flog_df['Program'].isin(['CSRP'])]

print(rlog_df.shape)
rlog_df.head()
# Out:
# (153, 9)
#     Event Date Administrator Program Start Time End Time Event Duration  \
# 178 2016-07-25    Con Edison    CSRP      11:00    15:00           4:00
# 179 2016-07-25    Con Edison    CSRP      14:00    18:00           4:00
# 180 2016-07-25    Con Edison    CSRP      16:00    20:00           4:00
# 181 2016-07-25    Con Edison    CSRP      19:00    23:00           4:00
# 187 2016-07-26    Con Edison    CSRP      11:00    15:00           4:00
#
#     Zone/Network Event/Test Event Type
# 178          All      Event    Planned
# 179          All      Event    Planned
# 180          All      Event    Planned
# 181          All      Event    Planned
# 187          All      Event    Planned

# %%
rlog_df.tail()
# Out:
#     Event Date Administrator Program Start Time End Time Event Duration  \
# 909 2024-07-17    Con Edison    CSRP      15:00    21:00           6:00
# 910 2024-07-17    Con Edison    CSRP      15:00    21:00           6:00
# 911 2024-07-17    Con Edison    CSRP      16:00    20:00           4:00
# 912 2024-07-17    Con Edison    CSRP      16:00    20:00           4:00
# 913 2024-07-17    Con Edison    CSRP      19:00    23:00           4:00
#
#     Zone/Network Event/Test    Event Type
# 909          All      Event  CSRP Planned
# 910    All SC 11      Event  CSRP Planned
# 911          All      Event  CSRP Planned
# 912    All SC 11      Event  CSRP Planned
# 913          All      Event  CSRP Planned

# %%
# this shows that more than 4 CSRP events per year for a given network is rare
# 2020 is an outlier in that it had many CSRP events that weren't for the entire network

# merge by day because CSRP events typically happen for all networks but redudant events are logged by call time
rD_s = rlog_df.groupby(rlog_df['Event Date'].dt.date).size()#.rename(columns={'size':'sum'})
#make a new data frame of event days
rY_s = pd.DataFrame({'dates':pd.to_datetime(rD_s.keys())})
#regroup by year
rY_s.groupby(rY_s['dates'].dt.year).size()
# Out:
# dates
# 2016     4
# 2018     4
# 2019     4
# 2020    19
# 2021     4
# 2022     6
# 2023     2
# 2024     3
# dtype: int64

# %%
rD_s
# Out:
# Event Date
# 2016-07-25     4
# 2016-07-26     4
# 2016-08-12     3
# 2016-08-15     4
# 2018-07-02     4
# 2018-08-28     4
# 2018-08-29     4
# 2018-09-06     4
# 2019-07-19     4
# 2019-07-20     4
# 2019-07-21     4
# 2019-08-19     4
# 2020-06-21     1
# 2020-06-25     1
# 2020-06-26     1
# 2020-06-27     1
# 2020-06-28     1
# 2020-06-29     1
# 2020-06-30     1
# 2020-07-01     1
# 2020-07-02     1
# 2020-07-05     1
# 2020-07-06     1
# 2020-07-07     1
# 2020-07-09     1
# 2020-07-20     1
# 2020-07-22     1
# 2020-07-27     2
# 2020-07-28     2
# 2020-07-29     1
# 2020-07-30     1
# 2021-06-29     4
# 2021-06-30     4
# 2021-08-12     4
# 2021-08-13     4
# 2022-07-20     4
# 2022-07-21     4
# 2022-08-04     4
# 2022-08-05     4
# 2022-08-08     4
# 2022-08-09     4
# 2023-07-28     7
# 2023-09-07     8
# 2024-07-15    10
# 2024-07-16    10
# 2024-07-17    10
# dtype: int64

# %%
# this shows that more than 4 CSRP events per year for a given network is rare
# 2020 is an outlier in that it had many CSRP events that weren't for the entire network

# merge by day because CSRP events typically happen for all networks but redudant events are logged by call time
rD_s = rlog_df[rlog_df['Zone/Network'].isin(['All','All^','Non-Manhattan**','Non-Manhattan***'])].groupby(rlog_df['Event Date'].dt.date).size()#.rename(columns={'size':'sum'})
#make a new data frame of event days
rY_s = pd.DataFrame({'dates':pd.to_datetime(rD_s.keys())})

#regroup by year
yS = rY_s.groupby(rY_s['dates'].dt.year).size()

#add 0 'all' events in to 2020
#yS.at['2020']=0

yS
# Out:
# dates
# 2016    4
# 2018    4
# 2019    4
# 2020    3
# 2021    4
# 2022    6
# 2023    2
# 2024    3
# dtype: int64

# %%
#average 'all' events
yS.mean()
# Out:
# np.float64(3.75)

# %%
yS.median()
# Out:
# np.float64(4.0)

# %%
median([4,4,4,3,4,2,3])
# Out:
# 4

# %%
yS
# Out:
# dates
# 2016    4
# 2018    4
# 2019    4
# 2020    3
# 2021    4
# 2022    6
# 2023    2
# 2024    3
# dtype: int64

# %% [markdown]
# ## DLRP Test Event Analysis

# %%
#filter out NYISO
tlog_df = log_df[log_df['Administrator']=='Con Edison']

#filter out non DLRP events
tlog_df = tlog_df[tlog_df['Program'].isin(['DLRP'])]

#filter out non-Test events
tlog_df = tlog_df[tlog_df['Event/Test'] == 'Test']

pd.set_option('display.max_rows', None)  # or 1000
display(tlog_df)
# Out:
#     Event Date Administrator Program Start Time End Time Event Duration  \
# 1   2011-06-08    Con Edison    DLRP      15:00    16:00           1:00
# 69  2013-06-26    Con Edison    DLRP      12:00    13:00           1:00
# 118 2014-06-26    Con Edison    DLRP      16:00    17:00           1:00
# 148 2015-06-24    Con Edison    DLRP      16:00    17:00           1:00
# 168 2016-07-13    Con Edison    DLRP      16:00    17:00           1:00
# 273 2017-07-18    Con Edison    DLRP      16:00    17:00           1:00
# 276 2017-07-31    Con Edison    DLRP      16:00    17:00           1:00
# 330 2018-07-16    Con Edison    DLRP      14:00    16:00           2:00
# 502 2019-08-20    Con Edison    DLRP      16:00    18:00           2:00
# 593 2020-08-24    Con Edison    DLRP      14:00    16:00           2:00
# 646 2021-07-27    Con Edison    DLRP      16:00    18:00           2:00
# 685 2022-07-18    Con Edison    DLRP      16:30    18:30           2:00
# 800 2022-07-14    Con Edison    DLRP      16:00    18:00           2:00
#
#     Zone/Network Event/Test Event Type
# 1            All       Test        NaN
# 69           All       Test        NaN
# 118          All       Test        NaN
# 148          All       Test        NaN
# 168          All       Test        NaN
# 273          All       Test        NaN
# 276          All       Test        NaN
# 330          All       Test       Test
# 502          All       Test       Test
# 593          All       Test       Test
# 646          All       Test       Test
# 685          All       Test       Test
# 800          All       Test       Test

# %%
#filter out pre-2016 data
tlog_df[tlog_df['Event Date'] > datetime.strptime('2016-01-01', '%Y-%m-%d')]
# Out:
#     Event Date Administrator Program Start Time End Time Event Duration  \
# 168 2016-07-13    Con Edison    DLRP      16:00    17:00           1:00
# 273 2017-07-18    Con Edison    DLRP      16:00    17:00           1:00
# 276 2017-07-31    Con Edison    DLRP      16:00    17:00           1:00
# 330 2018-07-16    Con Edison    DLRP      14:00    16:00           2:00
# 502 2019-08-20    Con Edison    DLRP      16:00    18:00           2:00
# 593 2020-08-24    Con Edison    DLRP      14:00    16:00           2:00
# 646 2021-07-27    Con Edison    DLRP      16:00    18:00           2:00
# 685 2022-07-18    Con Edison    DLRP      16:30    18:30           2:00
# 800 2022-07-14    Con Edison    DLRP      16:00    18:00           2:00
#
#     Zone/Network Event/Test Event Type
# 168          All       Test        NaN
# 273          All       Test        NaN
# 276          All       Test        NaN
# 330          All       Test       Test
# 502          All       Test       Test
# 593          All       Test       Test
# 646          All       Test       Test
# 685          All       Test       Test
# 800          All       Test       Test
