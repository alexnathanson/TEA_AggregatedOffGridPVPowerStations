# %% [markdown]
# # Model V5.2 Validation
#
# Run this mirroring the real data
#
# Real data used to validate uses Bluetti Elite 200 power stations, without any solar.
#
# 53 households, some with multiple batteries, performing in events over a 3-day period for a total of 237 individual event responses.
#
# Validation goals:
# * maximum flexibility

# %%
import pandas as pd
import numpy as np
import requests
import pvlib
import matplotlib.pyplot as plt  # for visualization
import math
from datetime import datetime
from statistics import median
from statistics import mean
from keys import *
from typing import List, Dict, Any
from collections import deque
import glob
import PySAM.Battery as battery

# %%
#GLOBALS
#note that these coordinates are the inputs for the NREL API,
#the coordinates used by the NREL API for the weather file are slightly different
#see below
lat = 40.7128
long = -74.0060

#optimize for summer when DR program is in effect
#also minimizes shading from buildings during PSH
tilt = lat #math.floor(lat - 15)

#default to south facing
azimuth = 180

print(f"tilt: {str(tilt)}, azimuth: {str(azimuth)}")

#14% losses
shading = .86

#max 99% efficient mppt battery charger - used for PV to battery
mppt = .99

# conversion rate when charging battery from grid - used for grid to battery
acToDC = .95

# microinverter conversion efficiency is 95% - used for PV to grid
miEff = 0.95

# max 80% depth of discharge for LiFePO4 batteries under normal circumstances
# & 95% to maximize flexibiltiy during events
LiFePOdod = 0.80
LiFePOdod_event = 0.96

#Max Hardware Sizes
pvMaxW = 1200

#PV degredation rate is assumed to be 1% annually
DEG_RATE = 0.01

#days in the months May - September
daysInMonth = [31,30,31,31,30]
drSeasonStartDay = 121

# self consumption of both controller and power station
controllerSC = 1 #Raspberry Pi Zero 2W controller self-consumption
powerStationSC = 8.62 #power station no-load self-consumption with AC outputs turned on
scWDC = controllerSC + powerStationSC
dailySelfConsumptionWhDC = scWDC * 24
# Out:
# tilt: 40.7128, azimuth: 180

# %% [markdown]
# # Validation Data

# %%
# ---- Load the real event-level observations ----
observed_df = pd.read_csv('power_station_validation/validation_hourly_observed_20260728_222814.csv')

# All deployed hardware is the same unit
BATTERY_MODEL = 'Elite 200V2'

observed_df.head()
# Out:
#    customer  battery_id battery_model  event  event_date  \
# 0         1           1   Elite 200V2      1  2025-06-23
# 1         1           1   Elite 200V2      1  2025-06-23
# 2         1           1   Elite 200V2      1  2025-06-23
# 3         1           1   Elite 200V2      1  2025-06-23
# 4         1           1   Elite 200V2      2  2025-06-24
#
#                    timestamp  hour_of_day     soc_pct  soc_pct_window_end  \
# 0  2025-06-23 16:00:00-04:00           16   97.066667           52.533333
# 1  2025-06-23 17:00:00-04:00           17   86.866667           52.533333
# 2  2025-06-23 18:00:00-04:00           18   63.066667           52.533333
# 3  2025-06-23 19:00:00-04:00           19   59.000000           52.533333
# 4  2025-06-24 16:00:00-04:00           16  100.000000           62.800000
#
#    observed_flex_kW  observed_load_kW  observed_grid_kW  \
# 0          0.174750          0.174750          0.000000
# 1          0.459417          0.459417          0.000000
# ...

# %%
observed_df.describe()
# Out:
#          customer  battery_id       event  hour_of_day     soc_pct  \
# count  924.000000  924.000000  924.000000   924.000000  923.000000
# mean    32.181818    1.350649    2.000000    16.772727   73.266685
# std     16.962691    0.529099    0.816939     1.933418   33.089280
# min      1.000000    1.000000    1.000000    11.000000    1.666667
# 25%     19.000000    1.000000    1.000000    16.000000   51.966667
# 50%     32.000000    1.000000    2.000000    17.000000   93.000000
# 75%     47.000000    2.000000    3.000000    18.000000   99.000000
# max     60.000000    3.000000    3.000000    22.000000  100.000000
#
#        soc_pct_window_end  observed_flex_kW  observed_load_kW  \
# count          920.000000        922.000000        922.000000
# mean            42.253892          0.262801          0.429487
# std             38.820533          0.327700          0.448966
# min              1.428571         -0.382783          0.000000
# ...

# %%
print(f'{len(observed_df['customer'].unique())} households')
print(f'events in data: {948.000000/4}')
# Out:
# 53 households
# events in data: 237.0

# %% [markdown]
# ## Power Station Data

# %%
hardware_df = pd.read_csv('data/PowerStations_LiFePo4_June29_2026.csv')

#clean data - these columns aren't used in this analysis
hardware_df = hardware_df.drop(columns=['Link','Min PV Voltage','Max PV Voltage','Warranty Years','Lifespan','Notes','Estimated Full Charge Time','Estimated Minimum Grid Charge Efficiency'])

retailPriceColumns = ['Retail Price (3/14/2026)']

# %%
pC = []
for c in hardware_df.columns:
    if 'Price (' in c:
        pC.append(c)

#get average retail prices
hardware_df['retail price']= hardware_df[retailPriceColumns].mean(axis=1)
hardware_df = hardware_df.drop(columns=pC) #drop raw price data

hardware_df = hardware_df.dropna(subset=['retail price']) #drop rows with missing avg prices

# %%
hardware_df = hardware_df[hardware_df['Model']==BATTERY_MODEL]

# 63.99% is the average 0-80% charge time for the full power station data set. Because the V200 full charge is under 2 hours, its not used anyway
hardware_df['80 Per Grid Charge Hours'] = hardware_df['Full Grid Charge Hours'] * 0.6399

#convert percentage to decimal
hardware_df['Inverter Efficiency'] = hardware_df['Inverter Efficiency']*.01

# price per Wh
hardware_df['$/Wh'] = hardware_df['retail price']/hardware_df['Battery Wh']

# %%
hardware_df
# Out:
#        Make        Model  Battery Wh  Max PV Watts  Max PV Amps  \
# 28  Bluetti  Elite 200V2      2073.0          1000         20.0
#
#     Inverter Watts  Max AC Input Watts  Full Grid Charge Hours  \
# 28          2600.0              1800.0                     1.4
#
#     80 Per Grid Charge Hours  Inverter Efficiency  Cycles  DoD Passthrough  \
# 28                   0.89586                  0.9    6000   80         NaN
#
#     community API  official API  potential API  retail price      $/Wh
# 28           True          True          False         799.0  0.385432

# %%
# ---- Pull the Elite 200V2 spec directly from hardware_df, instead of hardcoding ----

elite_row = hardware_df[hardware_df['Model'] == 'Elite 200V2'].iloc[0]

ELITE_200V2_SPEC = {
    'battery_Wh': float(elite_row['Battery Wh']),
    'max_pv_W': int(elite_row['Max PV Watts']),
    'max_pv_A': float(elite_row['Max PV Amps']),
    'inverter_W': float(elite_row['Inverter Watts']),
    'max_ac_input_W': float(elite_row['Max AC Input Watts']),
    'full_grid_charge_hours': float(elite_row['Full Grid Charge Hours']),
    'inverter_efficiency': float(elite_row['Inverter Efficiency']),
    'cycles': int(elite_row['Cycles']),
    'dod': float(elite_row['DoD']) / 100.0,   # hardware_df stores DoD as 80, not 0.80
    'retail_price': float(elite_row['retail price']),
}

print(ELITE_200V2_SPEC)
# Out:
# {'battery_Wh': 2073.0, 'max_pv_W': 1000, 'max_pv_A': 20.0, 'inverter_W': 2600.0, 'max_ac_input_W': 1800.0, 'full_grid_charge_hours': 1.4, 'inverter_efficiency': 0.9, 'cycles': 6000, 'dod': 0.8, 'retail_price': 799.0}

# %% [markdown]
# # Validation model

# %%
iE = ELITE_200V2_SPEC['inverter_efficiency']
batWh = ELITE_200V2_SPEC['battery_Wh']
dodFloor_event_Wh = batWh * (1 - LiFePOdod_event) #5% of the battery capacity

# %% [markdown]
# ## Validation w/ Known Loads and starting battery states

# %%
observed_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 924 entries, 0 to 923
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   customer                      924 non-null    int64
#  1   battery_id                    924 non-null    int64
#  2   battery_model                 924 non-null    str
#  3   event                         924 non-null    int64
#  4   event_date                    924 non-null    str
#  5   timestamp                     924 non-null    str
#  6   hour_of_day                   924 non-null    int64
#  7   soc_pct                       923 non-null    float64
#  8   soc_pct_window_end            920 non-null    float64
#  9   observed_flex_kW              922 non-null    float64
#  10  observed_load_kW              922 non-null    float64
#  11  observed_grid_kW              922 non-null    float64
#  12  observed_batterydischarge_kW  922 non-null    float64
# ...

# %%
INCLUDE_SOLAR = False  # flip once real PV data exists

# Model's OWN assumed event-DoD floor -- fixed, independent of any single
# event's outcome. Using observed SoC data here would be leakage.

max_discharge_kW = ELITE_200V2_SPEC['inverter_W'] * 0.001  # hardware rate cap

event_records = []

for (customer_num, battery_id, event_idx), g in observed_df.groupby(['customer', 'battery_id', 'event']):
    g = g.sort_values('timestamp').reset_index(drop=True)
    
    n_hours = len(g)

    observed_flex_kW = g['observed_flex_kW'].mean()
    #print(f'of:{observed_flex_kW}')
    observed_max_discharge_kW = g.loc[g['observed_flex_kW'] >= 0, 'observed_flex_kW'].max()
    #print(f'omd:{observed_max_discharge_kW}')
    observed_load_kW_mean = g['observed_load_kW'].mean()
    #print(f'ol:{observed_load_kW_mean}')


    soc_start_pct = g.iloc[0]['soc_pct']
    soc_end_pct = g.iloc[-1]['soc_pct_window_end']
    soc_pct = [soc_start_pct,g.iloc[1]['soc_pct'],g.iloc[2]['soc_pct'],g.iloc[3]['soc_pct'],soc_end_pct]

    if pd.isnull(soc_start_pct) or pd.isnull(soc_end_pct):
        continue
        
    pct_discharged = soc_start_pct - soc_end_pct
    batState_start_Wh = (soc_start_pct / 100.0) * batWh
    window_start_hour = int(g.iloc[0]['hour_of_day'])

    # total AC-equivalent kWh available down to the event DoD floor,
    # net of self-consumption over the window, as an average kW rate
    # maintains 5% dod floor
    predicted_max_battery_flex_kWAC = (
        max(0.0, (batState_start_Wh - dodFloor_event_Wh) - (powerStationSC * n_hours))
        * iE * 0.001 / n_hours
    )

    # # uses up to 95% of battery capacity, with a 1% floor
    # predicted_max_battery_flex_kWAC = (
    #     max(0.0, min((batState_start_Wh*0.99), (batWh * LiFePOdod_event)) - (powerStationSC * n_hours))
    #     * iE * 0.001 / n_hours
    # )

    # step hour-by-hour: cap by remaining capacity AND the hardware's rated
    # discharge power -- both units in kWh per hour (numerically = kW at 1hr resolution)
    remaining_capacity_kWh = predicted_max_battery_flex_kWAC * n_hours
    predicted_served_kWh = []
    for h in range(n_hours):
        predicted_served_kWh.append(min(remaining_capacity_kWh, g.iloc[h]['observed_load_kW'], max_discharge_kW))
        remaining_capacity_kWh = max(remaining_capacity_kWh - predicted_served_kWh[h], 0.0)

    predicted_actual_flex_kW = (predicted_max_battery_flex_kWAC * n_hours - remaining_capacity_kWh) / n_hours

    error_kW = predicted_actual_flex_kW - observed_flex_kW

    if observed_flex_kW > 0:
        accuracy_per = predicted_actual_flex_kW / observed_flex_kW
    elif (observed_flex_kW==0) & (predicted_actual_flex_kW ==0): # if it is accurately predicting 0 flex, it is 100% accurate
        accuracy_per = 1.0  
    else:
        accuracy_per = np.nan

    event_records.append({
        'customer': customer_num,
        'battery_id': battery_id,
        'event': event_idx,
        'window_start_hour': window_start_hour,
        'n_hours': n_hours,
        'soc_start_pct': soc_start_pct,
        'soc_end_pct': soc_end_pct,
        'soc_pct':soc_pct,
        'pct_discharged': pct_discharged,
        'observed_flex_kW': observed_flex_kW,
        'observed_max_discharge_kW': observed_max_discharge_kW,
        'observed_load_kW':list(g['observed_load_kW']),
        'observed_load_kW_mean': observed_load_kW_mean,
        'observed_grid_kW':list(g['observed_grid_kW']),
        'predicted_served_kWh': predicted_served_kWh, # the predicted hourly flex
        'predicted_max_battery_flex_kW': predicted_max_battery_flex_kWAC,
        'predicted_actual_flex_kW': predicted_actual_flex_kW,
        'error_kW': error_kW,
        'accuracy_per': accuracy_per,
    })

event_validation_df = pd.DataFrame(event_records)
print(f"Built {len(event_validation_df)} event-level predictions "
      f"for {event_validation_df['customer'].nunique()} households.")
event_validation_df.head()
# Out:
# Built 229 event-level predictions for 53 households.
#    customer  battery_id  event  window_start_hour  n_hours  soc_start_pct  \
# 0         1           1      1                 16        4      97.066667
# 1         1           1      2                 16        4     100.000000
# 2         1           1      3                 16        4      98.666667
# 3         3           1      1                 16        4     100.000000
# 4         3           1      2                 16        4     100.000000
#
#    soc_end_pct                                            soc_pct  \
# 0    52.533333  [97.06666666666666, 86.86666666666666, 63.0666...
# 1    62.800000  [100.0, 95.46666666666668, 84.4, 73.2666666666...
# 2    57.133333  [98.66666666666669, 87.8, 77.06666666666666, 6...
# 3    23.200000  [100.0, 81.33333333333333, 63.93333333333333, ...
# 4    19.800000  [100.0, 84.33333333333333, 63.333333333333336,...
#
#    pct_discharged  observed_flex_kW  observed_max_discharge_kW  \
# ...

# %%
event_validation_df.describe()
# Out:
#          customer  battery_id       event  window_start_hour  n_hours  \
# count  229.000000  229.000000  229.000000         229.000000    229.0
# mean    32.227074    1.353712    2.004367          15.266376      4.0
# std     17.056690    0.531257    0.819166           1.584950      0.0
# min      1.000000    1.000000    1.000000          11.000000      4.0
# 25%     19.000000    1.000000    1.000000          14.000000      4.0
# 50%     32.000000    1.000000    2.000000          16.000000      4.0
# 75%     47.000000    2.000000    3.000000          16.000000      4.0
# max     60.000000    3.000000    3.000000          19.000000      4.0
#
#        soc_start_pct  soc_end_pct  pct_discharged  observed_flex_kW  \
# count     229.000000   229.000000      229.000000        229.000000
# mean       96.979330    42.270722       54.708609          0.262030
# std         8.246945    38.968391       37.563740          0.190554
# ...

# %% [markdown]
# ### filter results

# %%
# remove rows that draw power from the grid when battery capacity is still available
charge_rows=[]
for i, r in event_validation_df.iterrows():
    for h in range(3):
        if (r['soc_pct'][h+1]>40) & (r['observed_grid_kW'][h]> 0.01) & (r['soc_pct'][h]>5):
            charge_rows.append(i)
            continue
print(charge_rows)
#print(len(event_validation_df.iloc[charge_rows]))
#event_validation_df.iloc[~charge_rows]

#event_validation_df = event_validation_df[~event_validation_df['accuracy_per'].isnull()]
event_validation_df = event_validation_df.drop(index=event_validation_df.index[charge_rows])
# Out:
# [1, 3, 4, 6, 7, 19, 19, 19, 20, 20, 21, 22, 31, 33, 34, 36, 37, 42, 45, 46, 48, 49, 57, 60, 63, 63, 64, 64, 64, 65, 65, 66, 66, 67, 67, 68, 68, 69, 70, 72, 73, 78, 87, 92, 93, 95, 96, 103, 104, 106, 107, 109, 110, 113, 124, 124, 124, 125, 126, 133, 134, 142, 143, 145, 146, 148, 149, 151, 152, 154, 155, 157, 158, 160, 161, 164, 167, 172, 173, 178, 179, 181, 187, 188, 191, 193, 196, 209, 215, 218, 221]

# %%
# filter out results with high grid draw for unknown reasons
event_validation_df = event_validation_df[~event_validation_df['accuracy_per'].isnull()]

# drop these rows, which both relied on grid power instead of their battery for an unknown reason
event_validation_df = event_validation_df[~((event_validation_df['customer']==19)&(event_validation_df['battery_id']==2)&(event_validation_df['event']==1))].reset_index(drop=True)
event_validation_df = event_validation_df[~((event_validation_df['customer']==17)&(event_validation_df['battery_id']==1)&(event_validation_df['event']==2))].reset_index(drop=True)

# %%
len(event_validation_df['customer'].unique())
# Out:
# 51

# %% [markdown]
# ### Prediction Accuracy

# %%
event_validation_df.describe()
# Out:
#          customer  battery_id       event  window_start_hour  n_hours  \
# count  150.000000  150.000000  150.000000         150.000000    150.0
# mean    33.146667    1.360000    2.220000          15.460000      4.0
# std     17.643900    0.534451    0.842416           1.705223      0.0
# min      1.000000    1.000000    1.000000          11.000000      4.0
# 25%     18.250000    1.000000    1.000000          14.000000      4.0
# 50%     33.000000    1.000000    2.000000          16.000000      4.0
# 75%     49.000000    2.000000    3.000000          16.000000      4.0
# max     60.000000    3.000000    3.000000          19.000000      4.0
#
#        soc_start_pct  soc_end_pct  pct_discharged  observed_flex_kW  \
# count     150.000000   150.000000      150.000000        150.000000
# mean       95.748889    53.154857       42.594032          0.204476
# std         9.788640    40.353794       37.255488          0.191391
# ...

# %%
# count highly accurate predictions
print(f'total samples: {len(event_validation_df)}')
vhigh_df=event_validation_df[(1- event_validation_df['accuracy_per']).abs() <= .01].copy()
print(f'{len(vhigh_df)/len(event_validation_df)}% ({len(vhigh_df)}) were >99% aligned with the observed data')

high_df=event_validation_df[((1- event_validation_df['accuracy_per']).abs() <= .05) & ((1- event_validation_df['accuracy_per']).abs() > .01)].copy()
print(f'{len(high_df)/len(event_validation_df)}% ({len(high_df)}) of were >95% aligned with the observed data')

lhigh_df=event_validation_df[((1- event_validation_df['accuracy_per']).abs() <= .1) & ((1- event_validation_df['accuracy_per']).abs() > .05)].copy()
print(f'{len(lhigh_df)/len(event_validation_df)}% ({len(lhigh_df)}) of were >90% aligned with the observed data')

outlier_df=event_validation_df[((1- event_validation_df['accuracy_per']).abs() > .1)].copy()
print(f'{len(outlier_df)/len(event_validation_df)}% ({len(outlier_df)}) of were <90% aligned with the observed data')

outlier_df.describe()
# Out:
# total samples: 150
# 0.6866666666666666% (103) were >99% aligned with the observed data
# 0.07333333333333333% (11) of were >95% aligned with the observed data
# 0.09333333333333334% (14) of were >90% aligned with the observed data
# 0.14666666666666667% (22) of were <90% aligned with the observed data
#         customer  battery_id      event  window_start_hour  n_hours  \
# count  22.000000   22.000000  22.000000          22.000000     22.0
# mean   32.818182    1.272727   2.681818          14.954545      4.0
# std    14.689278    0.455842   0.716231           1.785584      0.0
# min     3.000000    1.000000   1.000000          11.000000      4.0
# 25%    26.250000    1.000000   3.000000          14.000000      4.0
# 50%    34.000000    1.000000   3.000000          16.000000      4.0
# 75%    41.750000    1.750000   3.000000          16.000000      4.0
# max    58.000000    2.000000   3.000000          16.000000      4.0
#
# ...

# %%
plot_df = event_validation_df.dropna(subset=['accuracy_per']).copy()

# fixed-width bins across the observed load range
n_bins = 10
load_min = plot_df['predicted_actual_flex_kW'].min()
load_max = plot_df['predicted_actual_flex_kW'].max()
bin_edges = np.linspace(load_min, load_max, n_bins + 1)

plot_df['predicted flex'] = pd.cut(plot_df['predicted_actual_flex_kW'], bins=bin_edges, include_lowest=True)

load_bucket_summary = (
    plot_df.groupby('predicted flex', observed=True)
    .agg(
        n_events=('accuracy_per', 'size'),
        mean_accuracy_per=('accuracy_per', 'mean'),
        median_accuracy_per=('accuracy_per', 'median'),
        std_accuracy_per=('accuracy_per', 'std'),
    )
    .reset_index()
)

print(f"{len(plot_df)} events across {n_bins} load buckets "
      f"(range: {load_min:.2f}–{load_max:.2f} kW)")
load_bucket_summary
# Out:
# 150 events across 10 load buckets (range: 0.00–0.44 kW)
#     predicted flex  n_events  mean_accuracy_per  median_accuracy_per  \
# 0  (-0.001, 0.044]        56           1.000000             1.000000
# 1   (0.044, 0.088]         8           1.003380             1.000000
# 2   (0.088, 0.132]         4           0.924258             1.000000
# 3   (0.132, 0.176]         6           0.965526             1.000000
# 4    (0.176, 0.22]        10           1.001876             1.000000
# 5    (0.22, 0.264]         3           1.000000             1.000000
# 6   (0.264, 0.308]         5           0.971338             1.000000
# 7   (0.308, 0.352]         7           0.973606             1.000000
# 8   (0.352, 0.396]        17           0.935709             0.908909
# 9    (0.396, 0.44]        34           0.933113             0.936508
#
#    std_accuracy_per
# 0      6.759857e-16
# 1      9.561304e-03
# 2      1.514838e-01
# 3      8.643866e-02
# 4      5.932896e-03
# 5      0.000000e+00
# ...

# %%
plot_df = event_validation_df.dropna(subset=['accuracy_per', 'predicted_actual_flex_kW'])
n_total = len(event_validation_df)
n_excluded = n_total - len(plot_df)

median_accuracy_all = plot_df['accuracy_per'].median()
median_accuracy_high = plot_df[plot_df['predicted_actual_flex_kW']>=0.396]['accuracy_per'].median()


fig, ax = plt.subplots(figsize=(8, 6))
ax.scatter(plot_df['accuracy_per'], plot_df['predicted_actual_flex_kW'],
           alpha=0.6, color='tab:blue', edgecolor='white', linewidth=0.5)
ax.axvline(1.0, color='black', linestyle='-', linewidth=1, alpha=0.6,
           label='perfect prediction (1.0)')
ax.axvline(median_accuracy_all, color='tab:red', linestyle='--', linewidth=2,
           label=f'median accuracy (all) = {median_accuracy_all:.2f}')
ax.axvline(median_accuracy_high, color='tab:red', linestyle=':', linewidth=2,
           label=f'median accuracy (highest 10% predictions) = {median_accuracy_high:.2f}')
ax.set_xlabel('Accuracy percentage (predicted / observed)')
ax.set_ylabel('Predicted flex (kW)')
ax.set_title(
    f'Accuracy Ratio vs Predicted Flexibility\n'
    f'({len(plot_df)} observed events;)'
)
ax.grid(True, linestyle='-', linewidth=0.5, alpha=0.4)
ax.legend()
plt.tight_layout()

timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
outfile = f'prediction_accuracy_{timestamp}.png'
plt.savefig(outfile, dpi=300, bbox_inches='tight')
print(f"Saved plot to {outfile}")


plt.show()
# Out:
# Saved plot to prediction_accuracy_20260729_194314.png

# %%
# # kind of interesting but not needed
# plot_df = event_validation_df.dropna(subset=['accuracy_per']).copy()

# # fixed-width bins across the observed load range
# n_bins = 8
# load_min = plot_df['observed_load_kW_mean'].min()
# load_max = plot_df['observed_load_kW_mean'].max()
# bin_edges = np.linspace(load_min, load_max, n_bins + 1)

# plot_df['load_bucket'] = pd.cut(plot_df['observed_load_kW_mean'], bins=bin_edges, include_lowest=True)

# load_bucket_summary = (
#     plot_df.groupby('load_bucket', observed=True)
#     .agg(
#         n_events=('accuracy_per', 'size'),
#         mean_accuracy_per=('accuracy_per', 'mean'),
#         median_accuracy_per=('accuracy_per', 'median'),
#         std_accuracy_per=('accuracy_per', 'std'),
#     )
#     .reset_index()
# )

# print(f"{len(plot_df)} events across {n_bins} load buckets "
#       f"(range: {load_min:.2f}–{load_max:.2f} kW)")
# load_bucket_summary

# %%
n_total = len(event_validation_df)
n_nan = event_validation_df['accuracy_per'].isna().sum()
accuracy_valid = event_validation_df['accuracy_per'].dropna()

median_acc = accuracy_valid.median()

fig, ax = plt.subplots(figsize=(8, 5))
counts, bin_edges, bars = ax.hist(accuracy_valid, bins=25,
                                   color='tab:blue', alpha=0.75, edgecolor='white')

# label each non-empty bar with its bin center
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
for count, bar, center in zip(counts, bars, bin_centers):
    if count > 0:
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
                 f'{center:.2f}', ha='center', va='bottom', fontsize=8, rotation=90)

ax.axvline(1.0, color='black', linestyle='-', linewidth=1, alpha=0.6,
           label='perfect prediction (1.0)')
ax.axvline(median_acc, color='tab:red', linestyle='--', linewidth=2,
           label=f'Median = {median_acc:.2f}')

ax.set_xlabel('accuracy_per (predicted / observed)')
ax.set_ylabel('Number of events')
ax.set_title(
    f'Distribution of Prediction Accuracy Ratio\n'
    f'({len(accuracy_valid)} of {n_total} events; {n_nan} excluded)'
)
ax.legend()
plt.tight_layout()
plt.show()

# %%
hl_validation_df = event_validation_df[event_validation_df['predicted_actual_flex_kW']>=0.396]

n_total = len(hl_validation_df)
n_nan = hl_validation_df['accuracy_per'].isna().sum()
accuracy_valid = hl_validation_df['accuracy_per'].dropna()

median_acc = accuracy_valid.median()

fig, ax = plt.subplots(figsize=(8, 5))
counts, bin_edges, bars = ax.hist(accuracy_valid, bins=25,
                                   color='tab:blue', alpha=0.75, edgecolor='white')

# label each non-empty bar with its bin center
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
for count, bar, center in zip(counts, bars, bin_centers):
    if count > 0:
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
                 f'{center:.2f}', ha='center', va='bottom', fontsize=8, rotation=90)

ax.axvline(1.0, color='black', linestyle='-', linewidth=1, alpha=0.6,
           label='perfect prediction (1.0)')
ax.axvline(median_acc, color='tab:red', linestyle='--', linewidth=2,
           label=f'Median = {median_acc:.2f}')

ax.set_xlabel('accuracy_per (predicted / observed)')
ax.set_ylabel('Number of events')
ax.set_title(
    f'Distribution of Prediction Accuracy Ratio w/ observed flex > .4kW\n'
    f'({len(accuracy_valid)} of {n_total} events; {n_nan} excluded, observed_flex_kW ≈ 0)'
)
ax.legend()
plt.tight_layout()
plt.show()

# %%
hl_validation_df = event_validation_df[(event_validation_df['predicted_actual_flex_kW']<=0.396)]

n_total = len(hl_validation_df)
n_nan = hl_validation_df['accuracy_per'].isna().sum()
accuracy_valid = hl_validation_df['accuracy_per'].dropna()

median_acc = accuracy_valid.median()

fig, ax = plt.subplots(figsize=(8, 5))
counts, bin_edges, bars = ax.hist(accuracy_valid, bins=25,
                                   color='tab:blue', alpha=0.75, edgecolor='white')

# label each non-empty bar with its bin center
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
for count, bar, center in zip(counts, bars, bin_centers):
    if count > 0:
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
                 f'{center:.2f}', ha='center', va='bottom', fontsize=8, rotation=90)

ax.axvline(1.0, color='black', linestyle='-', linewidth=1, alpha=0.6,
           label='perfect prediction (1.0)')
ax.axvline(median_acc, color='tab:red', linestyle='--', linewidth=2,
           label=f'Median = {median_acc:.2f}')

ax.set_xlabel('accuracy_per (predicted / observed)')
ax.set_ylabel('Number of events')
ax.set_title(
    f'Distribution of Prediction Accuracy Ratio w/ observed flex < .4kW\n'
    f'({len(accuracy_valid)} of {n_total} events; {n_nan} excluded, observed_flex_kW ≈ 0)'
)
ax.legend()
plt.tight_layout()
plt.show()

# %%
# plot_df = event_validation_df.dropna(subset=['accuracy_per'])
# n_total = len(event_validation_df)
# n_nan = n_total - len(plot_df)

# fig, ax = plt.subplots(figsize=(8, 6))
# ax.scatter(plot_df['accuracy_per'], plot_df['predicted_actual_flex_kW'],
#            alpha=0.6, color='tab:blue', edgecolor='white', linewidth=0.5)

# ax.axvline(1.0, color='black', linestyle='-', linewidth=1, alpha=0.6,
#            label='perfect prediction (1.0)')

# ax.set_xlabel('accuracy_per (predicted / observed)')
# ax.set_ylabel('observed_flex_kW')
# ax.set_title(
#     f'Accuracy Ratio vs Observed Flexibility\n'
#     f'({len(plot_df)} of {n_total} events; {n_nan} excluded, observed_flex_kW ≈ 0)'
# )
# ax.legend()
# plt.tight_layout()
# plt.show()

# %% [markdown]
# #### Explore outliers

# %%
outliers_df=event_validation_df[(1- event_validation_df['accuracy_per']).abs() > .1].copy()
outliers_df.describe()
# Out:
#         customer  battery_id      event  window_start_hour  n_hours  \
# count  22.000000   22.000000  22.000000          22.000000     22.0
# mean   32.818182    1.272727   2.681818          14.954545      4.0
# std    14.689278    0.455842   0.716231           1.785584      0.0
# min     3.000000    1.000000   1.000000          11.000000      4.0
# 25%    26.250000    1.000000   3.000000          14.000000      4.0
# 50%    34.000000    1.000000   3.000000          16.000000      4.0
# 75%    41.750000    1.750000   3.000000          16.000000      4.0
# max    58.000000    2.000000   3.000000          16.000000      4.0
#
#        soc_start_pct  soc_end_pct  pct_discharged  observed_flex_kW  \
# count      22.000000    22.000000       22.000000         22.000000
# mean       83.596970     4.796970       78.800000          0.416929
# std        18.215169     0.396000       18.128186          0.089828
# min        26.666667     4.000000       21.666667          0.140546
# ...

# %%
# n_examples = 22  # how many events to plot
# picks = outliers_df.head(n_examples)

# fig, axes = plt.subplots(n_examples, 1, figsize=(13, 4.5 * n_examples), squeeze=False)

# for i, (_, row) in enumerate(picks.iterrows()):
#     ax = axes[i, 0]
#     g = observed_df[
#         (observed_df['customer'] == row['customer']) &
#         (observed_df['battery_id'] == row['battery_id']) &
#         (observed_df['event'] == row['event'])
#     ].sort_values('timestamp').reset_index(drop=True)
#     hours = np.arange(len(g))

#     width = 0.2
#     load_bars = ax.bar(hours - 1.5 * width, g['observed_load_kW'], width=width,
#                         label='observed_load_kW', color='steelblue', alpha=0.8)
#     flex_bars = ax.bar(hours - 0.5 * width, g['observed_flex_kW'], width=width,
#                         label='observed_flex_kW', color='darkorange', alpha=0.8)
#     pred_served_bars = ax.bar(hours + 0.5 * width, row['predicted_served_kWh'], width=width,
#                         label='predicted_served_kW', color='pink', alpha=0.8)
#     grid_bars = ax.bar(hours + 1.5 * width, g['observed_grid_kW'], width=width,
#                         label='observed_grid_kW', color='mediumpurple', alpha=0.8)

#     # label each bar with its value
#     ax.bar_label(load_bars, fmt='%.2f', fontsize=7, padding=2, rotation=90)
#     ax.bar_label(flex_bars, fmt='%.2f', fontsize=7, padding=2, rotation=90)
#     ax.bar_label(pred_served_bars, fmt='%.2f', fontsize=7, padding=2, rotation=90)
#     ax.bar_label(grid_bars, fmt='%.2f', fontsize=7, padding=2, rotation=90)

#     mean_flex_line = ax.axhline(row['observed_flex_kW'], color='darkorange', linestyle='--',
#                                  linewidth=1, label='event mean observed_flex_kW')
#     pred_flex_line = ax.axhline(row['predicted_actual_flex_kW'], color='crimson', linestyle='--',
#                                  linewidth=1, label='predicted_actual_flex_kW')

#     ax.set_xticks(hours)
#     ax.set_xlabel('hour into event')
#     ax.set_ylabel('kW')
#     # leave headroom above the tallest bar for the rotated labels
#     ax.set_ylim(0, max(g['observed_load_kW'].max(),
#                         np.max(row['predicted_served_kWh']),
#                         g['observed_flex_kW'].max(),
#                         g['observed_grid_kW'].max()) * 1.4)
#     ax.set_title(
#         f"customer {row['customer']} | battery {row['battery_id']} | event {row['event']} "
#         f"(accuracy: {row['accuracy_per']:.1%}, n_hours={row['n_hours']})"
#     )

#     # SoC on secondary axis, with a value label at each point
#     ax2 = ax.twinx()
#     soc_line, = ax2.plot(hours, g['soc_pct'], color='green', marker='o', markersize=3,
#                           linewidth=1, alpha=0.6, label='soc_pct')
#     for x, y in zip(hours, g['soc_pct']):
#         ax2.annotate(f'{y:.0f}%', (x, y), textcoords='offset points',
#                      xytext=(0, 6), fontsize=7, color='green', ha='center')
#     ax2.set_ylabel('SoC (%)', color='green')
#     ax2.tick_params(axis='y', labelcolor='green')
#     ax2.set_ylim(0, 108)  # headroom for the top labels

#     # combine both axes' legend handles into one legend, placed outside the plot
#     handles = [load_bars, flex_bars, pred_served_bars, grid_bars,
#                mean_flex_line, pred_flex_line, soc_line]
#     labels = [h.get_label() for h in handles]
#     ax.legend(handles, labels, fontsize=8, loc='upper left',
#               bbox_to_anchor=(1.08, 1.0))

# plt.tight_layout()
# plt.show()

# %% [markdown]
# ### Explore Max Flex

# %%
median_flex = event_validation_df['observed_flex_kW'].median()

fig, ax = plt.subplots(figsize=(8, 5))
ax.hist(event_validation_df['observed_flex_kW'], bins=20, color='tab:blue', alpha=0.75, edgecolor='white')
ax.axvline(median_flex, color='tab:red', linestyle='--', linewidth=2,
           label=f'Median = {median_flex:.2f} kW')

ax.set_xlabel('Observed flexibility (kW)')
ax.set_ylabel('Number of events')
ax.set_title('Distribution of Observed Flexibility Across Events')
ax.legend()

plt.tight_layout()
plt.show()

# %%
event_validation_df[['pct_discharged','observed_flex_kW']].describe()
# Out:
#        pct_discharged  observed_flex_kW
# count      150.000000        150.000000
# mean        42.594032          0.204476
# std         37.255488          0.191391
# min          1.000000          0.000000
# 25%          2.000000          0.000000
# 50%         40.200000          0.182846
# 75%         83.650000          0.426481
# max         95.000000          0.481608

# %%
event_validation_df[event_validation_df['pct_discharged']==95].describe()
# Out:
#         customer  battery_id    event  window_start_hour  n_hours  \
# count   6.000000    6.000000  6.00000           6.000000      6.0
# mean   33.500000    1.500000  2.50000          15.333333      4.0
# std    24.517341    0.547723  0.83666           1.032796      0.0
# min     3.000000    1.000000  1.00000          14.000000      4.0
# 25%    12.750000    1.000000  2.25000          14.500000      4.0
# 50%    37.000000    1.500000  3.00000          16.000000      4.0
# 75%    54.500000    2.000000  3.00000          16.000000      4.0
# max    59.000000    2.000000  3.00000          16.000000      4.0
#
#        soc_start_pct  soc_end_pct  pct_discharged  observed_flex_kW  \
# count            6.0          6.0             6.0          6.000000
# mean           100.0          5.0            95.0          0.464651
# std              0.0          0.0             0.0          0.019445
# min            100.0          5.0            95.0          0.438242
# ...

# %%
event_validation_df[event_validation_df['observed_flex_kW']>0.44][['observed_flex_kW','predicted_actual_flex_kW','accuracy_per','pct_discharged']]
# Out:
#      observed_flex_kW  predicted_actual_flex_kW  accuracy_per  pct_discharged
# 2            0.471462                  0.413579      0.877226       89.333333
# 3            0.481608                  0.440010      0.913626       95.000000
# 13           0.462104                  0.440010      0.952188       95.000000
# 14           0.472167                  0.396166      0.839039       86.600000
# 15           0.444808                  0.426017      0.957755       92.000000
# 24           0.461733                  0.399586      0.865405       86.333333
# 25           0.455887                  0.430992      0.945392       93.066667
# 41           0.449337                  0.423219      0.941873       91.400000
# 55           0.448921                  0.424152      0.944825       88.600000
# 60           0.446162                  0.393678      0.882366       85.066667
# 65           0.470133                  0.417311      0.887643       90.000000
# ...

# %%
from matplotlib.ticker import MultipleLocator

plot_df = event_validation_df.dropna(subset=['observed_flex_kW', 'pct_discharged'])
fig, ax = plt.subplots(figsize=(8, 6))
ax.scatter(plot_df['pct_discharged'], plot_df['observed_flex_kW'],
           alpha=0.6, color='tab:blue', edgecolor='white', linewidth=0.5,
           label='observed events')
# linear trend line
slope, intercept = np.polyfit(plot_df['pct_discharged'], plot_df['observed_flex_kW'], 1)
x_line = np.linspace(plot_df['pct_discharged'].min(), plot_df['pct_discharged'].max(), 100)
y_line = slope * x_line + intercept
ax.plot(x_line, y_line, color='tab:red', linestyle='--', linewidth=2,
        label=f'observed: y = {slope:.4f}x + {intercept:.3f}')
# standard deviation of residuals around the trend line, shown as shaded bands
residuals = plot_df['observed_flex_kW'] - (slope * plot_df['pct_discharged'] + intercept)
resid_std = residuals.std()
ax.fill_between(x_line, y_line - 2 * resid_std, y_line + 2 * resid_std,
                 color='tab:red', alpha=0.08, label=f'±2 SD = {2 * resid_std:.3f} kW')
ax.fill_between(x_line, y_line - resid_std, y_line + resid_std,
                 color='tab:red', alpha=0.15, label=f'±1 SD = {resid_std:.3f} kW')
# theoretical relationship: x * (2073 - powerStationSC * 4) * 0.9 * 0.25
# x% * bat_kW-losses * 25%
y_theory = ((x_line * 0.01 * 2.0736) - (powerStationSC * 0.004)) * 0.9 * 0.25
ax.plot(x_line, y_theory, color='tab:green', linestyle='-', linewidth=2,
        label='model: (x(2.073) - (4*sc))·L)/4h')

ax.set_xlabel('Percent discharged during DR event (%)')
ax.set_ylabel('Flex (kW)')
ax.set_title('Flexibility vs Percent Discharged')

# more ticks on both axes
ax.xaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(0.25))
ax.tick_params(axis='both', labelsize=9)

# grid
ax.grid(True, which='major', linestyle='-', linewidth=0.5, alpha=0.4)
ax.grid(True, which='minor', linestyle=':', linewidth=0.3, alpha=0.2)
ax.minorticks_on()

ax.legend()
plt.tight_layout()


timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
outfile = f'observed_flex_vs_pct_discharged_{timestamp}.png'
plt.savefig(outfile, dpi=300, bbox_inches='tight')
print(f"Saved plot to {outfile}")

plt.show()
# Out:
# Saved plot to observed_flex_vs_pct_discharged_20260729_194337.png

# %%
2 sds = 0.4345

# %%
((95 * 0.01 * 2.073) - (powerStationSC * .004)) * 0.9 * 0.25
# Out:
# 0.43534575000000003

# %%
# o = []
# for p in range(95):
#     o.append(pvlib.inverter.pvwatts(((p * 0.01 * 2073) - (powerStationSC * 0.004)), 2600, .9) * 0.001 * 0.25)

# p_values = list(range(95))

# fig, ax = plt.subplots(figsize=(8, 6))
# ax.plot(p_values, o, color='tab:green', linewidth=2)

# ax.set_xlabel('p (pct_discharged)')
# ax.set_ylabel('modeled output (kW)')
# ax.set_title('PVWatts-based Model Output vs Percent Discharged')
# ax.grid(True, linestyle='-', linewidth=0.5, alpha=0.4)
# plt.tight_layout()
# plt.show()

# %%
soc_drop = (
    observed_df.sort_values('timestamp')
    .groupby(['customer', 'battery_id', 'event'])['soc_pct']
    .agg(soc_start_pct='first', soc_end_pct='last')
    .reset_index()
)
soc_drop['pct_discharged'] = soc_drop['soc_start_pct'] - soc_drop['soc_end_pct']

# drop any existing pct_discharged first so re-running this cell is safe
event_validation_df = event_validation_df.drop(columns=['pct_discharged'], errors='ignore')

event_validation_df = event_validation_df.merge(
    soc_drop[['customer', 'battery_id', 'event', 'pct_discharged']],
    on=['customer', 'battery_id', 'event'],
    how='left'
)

# ---- filter to events where battery dropped == 95% ----
deep_discharge_df = event_validation_df[event_validation_df['pct_discharged'] >=90]

print(f"{len(deep_discharge_df)} of {len(event_validation_df)} events dropped == 95% "
      f"({len(deep_discharge_df) / len(event_validation_df) * 100:.1f}%)")

median_flex = deep_discharge_df['observed_flex_kW'].median()
mean_flex = deep_discharge_df['observed_flex_kW'].mean()

fig, ax = plt.subplots(figsize=(8, 5))
counts, bin_edges, bars = ax.hist(deep_discharge_df['observed_flex_kW'], bins=20,
                                   color='tab:blue', alpha=0.75, edgecolor='white')

# label each non-empty bar with its bin center (x-axis value)
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
for count, bar, center in zip(counts, bars, bin_centers):
    if count > 0:
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
                 f'{center:.3f}', ha='center', va='bottom', fontsize=8, rotation=90)

ax.axvline(median_flex, color='tab:red', linestyle='--', linewidth=2,
           label=f'Median = {median_flex:.3f} kW')

ax.axvline(mean_flex, color='tab:pink', linestyle='--', linewidth=2,
           label=f'Mean = {median_flex:.3f} kW')

ax.set_xlabel('Observed flexibility (kW)')
ax.set_ylabel('Number of events')
ax.set_title('Observed Flexibility — Events with 95% SoC Drop')
ax.legend()

plt.tight_layout()
plt.show()
# Out:
# 7 of 150 events dropped == 95% (4.7%)

# %%
exceeded_df = event_validation_df[
    event_validation_df['observed_load_kW_mean'] > event_validation_df['observed_flex_kW']
]

print(f"{len(exceeded_df)} of {len(event_validation_df)} events had load exceeding flex "
      f"({len(exceeded_df) / len(event_validation_df) * 100:.1f}%)")

median_flex = exceeded_df['observed_flex_kW'].median()

fig, ax = plt.subplots(figsize=(8, 5))
ax.hist(exceeded_df['observed_flex_kW'], bins=20, color='tab:blue', alpha=0.75, edgecolor='white')
ax.axvline(median_flex, color='tab:red', linestyle='--', linewidth=2,
           label=f'Median = {median_flex:.2f} kW')

ax.set_xlabel('Observed flexibility (kW)')
ax.set_ylabel('Number of events')
ax.set_title('Observed Flexibility — Events Where Load Exceeded Flex (interesting, but not used in paper)')
ax.legend()

plt.tight_layout()
plt.show()
# Out:
# 42 of 150 events had load exceeding flex (28.0%)
